# %% [markdown]
# ## Count PRs created and JIRA tickets assigned per IC over last 4 months

# %% [markdown]
# **Make sure to run the 'Build Employees' notebook first to create the 'coders' view**

# %%
count github.coders
# Out:
# 1 row
#  count__
#       66

# %% [markdown]
# ### Count PRs by user over last 4 months

# %%
select
  count(*) as count, user_login
from
  github.pulls
where
  created_at > (now() - INTERVAL 4 month)
group by user_login
order by count desc
# Out:
# 133 rows
#  count            user_login
#    239              dansc0de
#    203         willis-tatari
#    187        stephen-tatari
#    161         henryzhangsta
#    160               pshelby
#    142                  lrod
#    139               nkbelow
#    104   patrick-strittmater
#    102              npalombo
#    101           dave-kimble
#     97        patrick-tatari
#     90          calvintatari
#     85               ellen-x
#     85             waegerter
#     78        rsty-instgrmpy
#     73          georgegaytan
#     69         margot-tatari
#     63               dgaldon
#     62               igandhi
#     62           helloimowen
#     61             alexkahan
#     60         keegan-tatari
#     54        claramartinez2
#     52        lucas-baik-ttv
#     52               tlovely
#     52           turing4ever
#     51          brian-tatari
#     51              dog-face
#     44             sevenfour
#     43            nick-kl4us
#     42             byingyang
#     42             benhorntv
#     41           alexfraczak
#     41             Gerald-DT
#     41           brandon733t
#     40           tataristaku
#     40    truxtencook-tatari
#     39              seanchon
#     39           Anna-Tatari
#     38              itsliana
#     37             KyleZouFE
#     37             tmoney100
#     37            andresgoag
#     36               jglopez
#     35             katiesing
#     35       Cody123Anderson
#     33           mike-tatari
#     33         TantumNTatari
#     33             janina213
#     31          kelly-tatari
#     31             Kyle-Dinh
#     30              moarwick
#     29           bobattatari
#     29              kyle-ttv
#     28 nathaniel-sandler-ttv
#     26           tonyooooooo
#     25       mikel-at-tatari
#     24            leah-z-liu
#     24               juanfec
#     23            vicortiz94
#     21      abstractmachines
#     20              sirtorry
#     20        travisd-tatari
#     19              will-vea
#     19         daniel-a-leon
#     19         BrianJFeldman
#     19             xueTatari
#     19    rahulsharma-tatari
#     18         JamesATrevino
#     17           tommytatari
#     17              kienankb
#     17           natanaelw67
#     17           Jeff-tatari
#     16           grigorovsky
#     16       dependabot[bot]
#     16               dShah81
#     16       tv-watts-tatari
#     16              rfarjadi
#     16          jianattatari
#     14             weitatari
#     14             mattpatch
#     14           simranpatil
#     14             linda-owo
#     14               nzlinus
#     13          joshua-demeo
#     13            onmywayout
#     11         puneet-tatari
#     11             Jaykim148
#     10             sabrinaan
#     10           yumeng-liao
#     10              robkwark
#      9         jessicatatari
#      9                  lame
#      8     computerGeologist
#      8            raychung02
#      8         escote-tatari
#      8     micahelias-tatari
#      7           manisha-pat
#      7          nickd-tatari
#      7             jp-tatari
#      7        timothydmorton
#      7            kabirdugal
#      7               glorp47
#      6       danharristatari
#      6               dfinlay
#      6             ajwhitley
#      6           Mfon-tatari
#      5               jpotth1
#      5        bryce-manhardt
#      5            jasonjylin
#      5         sakshi-tatari
#      4   danstynchula-tatari
#      4          summerrr0101
#      4             jkreschke
#      4                aspall
#      4                jeffcs
#      3           LucasMiller
#      3           zwangtatari
#      3      JimmyShao-tatari
#      3    keenanwells-tatari
#      3          anushamohan7
#      3        michael-tatari
#      2             spindle79
#      2             sshirokov
#      2             meetbryce
#      1              tatar-ye
#      1           mala-tatari
#      1 congcharlieqin-tatari
#      1           rudy-tatari
#      1            jervincruz
#      1        scottpersinger
#      1             jimlyndon
#      1     Owen-Karpf-Tatari

# %% [markdown]
# ### Now join to 'coders' view to get employee info

# %%
with pr_counts as (
    select
      count(*) as count, user_login
    from
      github.pulls
    where
      created_at > (now() - INTERVAL 4 month)
    group by user_login
    order by count desc
)
select 
  count, user_login, name, start, lvl, manager
from 
  pr_counts
inner join
  github.coders on pr_counts.user_login = github.coders.login
# Out:
# Table default.pr_counts does not exist

# %% [markdown]
# ### Now count JIRA tickets by person

# %%
  select 
     count(*) as count, assignee_displayName
  from 
     jira.issues
  where created > (now() - interval 4 month)
  group by assignee_displayName
  order by count desc
# Out:
# 175 rows
#  count    assignee_displayName
#   1531
#    370           Manisha Patel
#    142             Jervin Cruz
#    121         Bruce Rechichar
#     93            Anusha Mohan
#     89       Vitalii Litkevich
#     81           Michael Smith
#     74              Anna Young
#     73      Viacheslav Shostak
#     73            Victor Ortiz
#     73                Jeff Cai
#     70           Solomon Klein
#     65          Abdullah Spall
#     65      Vasily Grigorovsky
#     63              Ellen Xiao
#     62              Josh Demeo
#     61                Leah Liu
#     60             Tommy Hogan
#     59              Rifat Khan
#     58          Thuy-Van Watts
#     58              Ike Gandhi
#     56            David Galdon
#     55                Will Vea
#     55              Sabrina An
#     55                 Xue Gao
#     54            Kyle Kosnoff
#     52           Cody Anderson
#     52               Matt Agin
#     52          Bryce Manhardt
#     51            Leo Alekseev
#     50             Stan Kudrow
#     50         Majken Longlade
#     50               Ray Chung
#     48        William Aegerter
#     47            Tyler Lovely
#     45           Dmitriy Butko
#     45 Nataliia Myroshnychenko
#     44         Jordan Potthoff
#     43          Patrick Shelby
#     42              Matt Patch
#     41           Dan Stynchula
#     40            Yana Belokoz
#     40           Stephen Price
#     40              Alex Kahan
#     39         Willis Schubert
#     38             Dan Mahoney
#     38          Yevhen Shakhov
#     37               Rob Kwark
#     36             Jessica Cai
#     35        Roman Pavlushkov
#     35       Alessandro Gracia
#     35              Lucas Baik
#     35              Zishu Wang
#     34            David Kimble
#     34            Nick Palombo
#     34                Ben Horn
#     34     Alexandre Dieudonne
#     34           Taylor Allred
#     33            Nick Gentile
#     33      Jeremy Glenn Lopez
#     33            Owen Sanders
#     33 Leslie Rodriguez Garcia
#     32              Nick Below
#     31                  Ada Li
#     30           George Gaytan
#     30            Mike Swinson
#     28               Brian Sam
#     27            Janina Mejia
#     27            Bob Lockwood
#     26       Nathaniel Sandler
#     26           Liana Sanders
#     25        Anton Slobodskyi
#     24               Noah Vito
#     24           Russell Simco
#     24            Travis Doane
#     24     Patrick Strittmater
#     23            Brian Olecki
#     23               Sean Chon
#     23           Brian Feldman
#     22                 Jian Lu
#     22          Tantum Nilkaew
#     22              Katie Sing
#     22            Rudy Gilmore
#     22            Alex Fraczak
#     22             Kabir Dugal
#     22            Jake Reschke
#     21               Kyle Dinh
#     21           Calvin Morrow
#     20               JP Ciceri
#     20          Peter Morawiec
#     20            Jaeyeong Kim
#     19               Summer Ye
#     19                 Yi Wang
#     19            Amanda Falke
#     19    Clara Martinez Rubio
#     19         Keegan Ferrando
#     19                Kyle Zou
#     18                Toni Poe
#     18              Juan Rueda
#     18            Lucas Miller
#     18            Oleg Gubanov
#     17          Margot Maxwell
#     17              Tim Morton
#     17        Gerald Diep-Tran
#     17              Dhara Shah
#     16           Haris Qureshi
#     16          Mfon Afangideh
#     15          Polina Frolova
#     15              Owen Karpf
#     13               Ryan Kuhl
#     13              Jim Lyndon
#     12    Andres Gomez Agudelo
#     12             Maxwell Guo
#     12          Artem Bukariev
#     11           James Trevino
#     11              Torry Yang
#     11     Gennadii Kravchenko
#     10             Henry Zhang
#     10             Daniel Leon
#     10             Brandon Lee
#     10              Andrew Kim
#     10                Ty McRae
#     10             Brent White
#     10              Vlad Belik
#      9              Linda Wang
#      9            Truxten Cook
#      9              Patrick He
#      9     Kienan Knight-Boehm
#      9      Michael Collington
#      8         Natanael Wijaya
#      8             Tony O'Dell
#      8                Wei Chen
#      7           Puneet Nayyar
#      7             Brad Yinger
#      7           Mala Munisamy
#      6            Mike Bartoli
#      5         Elizabeth Spear
#      5            Keenan Wells
#      5            Mike Librodo
#      5               Jason Lin
#      5          Nicolas Zapata
#      5              Nick Davis
#      4            Rahul Sharma
#      4             Micah Elias
#      4            Ani Govindan
#      4             Tim Gumbley
#      4          Tyrone Chouhan
#      4            Yulia Koshel
#      3             Dave Finlay
#      3            Dima Dibrova
#      2         Kaitlin Rasborn
#      2           Russ O'Reagan
#      2             Yumeng Liao
#      2            Ryan Farjadi
#      2               David Hwu
#      2              Reno Brown
#      2                Annie Xu
#      2              Jimmy Shao
#      1            Simran Patil
#      1        Sergey Sadchikov
#      1        Erika Clingerman
#      1               Jena Vint
#      1           Daniel Harris
#      1              Mike Child
#      1            Iryna Kaplia
#      1              Jeff Stamm
#      1      Andrew Prysiazhnyi
#      1             Kelly Chung
#      1              Caleb Rouw
#      1             Scott Idler
#      1                 Gary Ye
#      1          Lin O'Driscoll
#      1           Harshal Dalvi
#      1           Yana Kyselova
#      1            Meagan Boggs

# %% [markdown]
# ### Now query both JIRA issues and PR counts together into a view

# %%
create or replace view github.prs_and_tickets as (
    with jira_issues as (
      select 
         count(*) as count, assignee_displayName as name
      from 
         jira.issues
      where created > (now() - interval 4 month)
      group by assignee_displayName
      order by count desc
    ),
    pr_counts as (
        select
          count(*) as count, user_login
        from
          github.pulls
        where
          created_at > (now() - INTERVAL 4 month)
        group by user_login
        order by count desc
    )
    select 
      user_login, github.coders.name, start, lvl, manager, pr_counts.count as prs, jira_issues.count as tickets
    from 
      pr_counts
    inner join
      github.coders on pr_counts.user_login = github.coders.login
    join
      jira_issues on ltrim(rtrim(lower(github.coders.name))) = ltrim(rtrim(lower(jira_issues.name)))
    order by (pr_counts.count + jira_issues.count) desc
)
# Out:
# Table default.pr_counts does not exist

# %%
select * from github.prs_and_tickets
# Out:
# 56 rows
#            user_login tenant_scottp_github____coders_name      start lvl manager  prs  tickets
#              dansc0de                         Dan Mahoney 2021-05-22   4   Idler  239       38
#         willis-tatari                     Willis Schubert 2022-04-09   1   Idler  203       39
#        stephen-tatari                       Stephen Price 2021-10-02   3  ScottI  187       40
#               pshelby                      Patrick Shelby 2020-11-07   4   Idler  160       43
#         henryzhangsta                         Henry Zhang 2019-11-30   5   Scott  161       10
#               nkbelow                          Nick Below 2019-11-02   3     Jim  139       32
#            jervincruz                         Jervin Cruz 2020-11-14   2  Barone    1      142
#              npalombo                        Nick Palombo 2021-08-30   4     Jim  102       34
#             waegerter                    William Aegerter 2020-10-31   5  Jeff S   85       48
#   patrick-strittmater                 Patrick Strittmater 2021-05-22   4   Scott  104       24
#               igandhi                          Ike Gandhi 2019-11-09   4   Peter   62       58
#               dgaldon                        David Galdon 2021-05-15   4   Peter   63       56
#          calvintatari                       Calvin Morrow 2021-04-24   3 Scott-I   90       21
#          georgegaytan                       George Gaytan 2019-10-27   3    Reno   73       30
#        rsty-instgrmpy                       Russell Simco 2021-06-26   3   Scott   78       24
#             alexkahan                          alex kahan 2022-05-30   1    Reno   61       40
#               tlovely                        Tyler Lovely 2021-12-04   4     Jim   52       47
#             sevenfour                        Leo Alekseev 2022-01-01   3   David   44       51
#           helloimowen                       Owen Sanders  2020-08-08   3   Scott   62       33
#           tataristaku                         Stan Kudrow 2022-06-25   4 Harshal   40       50
#        lucas-baik-ttv                          Lucas Baik 2021-11-29   4    Mala   52       35
#       Cody123Anderson                       Cody Anderson 2021-04-24   4     Jim   35       52
#         margot-tatari                      Margot Maxwell 2022-04-23   3   Idler   69       17
#            leah-z-liu                            Leah Liu 2021-03-20   2   Bruce   24       61
#         keegan-tatari                     Keegan Ferrando 2021-10-30   4   Idler   60       19
#            nick-kl4us                        Nick Gentile 2021-08-07   3    Mala   43       33
#          brian-tatari                        Brian Olecki 2021-05-22   4    Reno   51       23
#        claramartinez2                Clara Martinez Rubio 2022-04-16   3    Mala   54       19
#             tmoney100                       Taylor Allred 2021-09-25   3     Jim   37       34
#           turing4ever                             Yi Wang 2020-10-17   4     Jim   52       19
#               jglopez                  Jeremy Glenn Lopez 2021-05-22   3 Scott-I   36       33
#              itsliana                       Liana Sanders 2019-10-26   3   Peter   38       26
#           alexfraczak                        Alex Fraczak 2021-08-28   4    Reno   41       22
#              seanchon                           Sean Chon 2020-11-07   4   David   39       23
#             janina213                        Janina Mejia 2019-01-05   3     Jim   33       27
#            raychung02                           Ray Chung 2021-01-16   2  Barone    8       50
#             Gerald-DT                    Gerald Diep-Tran 2022-01-22   3     Jim   41       17
#             katiesing                          Katie Sing 2021-06-05   2    Mala   35       22
#             KyleZouFE                            Kyle Zou 2021-08-30   2   David   37       19
#           bobattatari                        Bob Lockwood 2021-11-13   3   David   29       27
#         TantumNTatari                      Tantum Nilkaew 2022-03-13   1   David   33       22
# nathaniel-sandler-ttv                   Nathaniel Sandler 2022-03-26   3    Mala   28       26
#           brandon733t                         Brandon Lee 2021-08-14   4  Jeff S   41       10
#             byingyang                         Brad Yinger 2020-10-04   4  Jeff S   42        7
#               jpotth1                     Jordan Potthoff 2021-06-12   4   Bruce    5       44
#        travisd-tatari                        Travis Doane 2021-10-16   3    Reno   20       24
#         BrianJFeldman                       Brian Feldman 2018-09-03   4    Mala   19       23
#           mike-tatari                        Mike Bartoli 2022-04-30   4    Jeff   33        6
#               dShah81                          Dhara Shah 2022-01-08   4    Mala   16       17
#              sirtorry                          Torry Yang 2022-03-26   2    Mala   20       11
#         JamesATrevino                       James Trevino 2022-01-01   3     Jim   18       11
#         daniel-a-leon                         Daniel Leon 2021-02-27   2     Jim   19       10
#             jp-tatari                           JP Ciceri 2021-12-05   2   Dan S    7       20
#                  lame                           Ryan Kuhl 2018-11-24   4  Jeff S    9       13
#              rfarjadi                        Ryan Farjadi 2017-07-08   5   Scott   16        2
#    keenanwells-tatari                        Keenan Wells 2022-06-25   3    Reno    3        5

# %% [markdown]
# ### And now export the view to Google Sheets

# %%
$name='PRs and Ticket stats - ' || cast(date_trunc('day',now()) as varchar)
# Out:
# PRs and Ticket stats - 2022-11-11 00:00:00

# %%
$name
# Out:
# PRs and Ticket stats - 2022-11-11 00:00:00

# %%
export github.prs_and_tickets to gsheets $name overwrite
# Out:
# Wrote 57 rows to sheet
# Exported query result to 'PRs and Ticket stats - 2022-11-11 00:00:00'

# %%
email github.prs_and_tickets to 'scottp@berkeleyzone.net'
# Out:
# Emailing github.prs_and_tickets to ['scottp@berkeleyzone.net']

# %%
export github.prs_and_tickets to 'ic_stats.xlsx'
# Out:
# Exported query result to 'ic_stats.xlsx'
