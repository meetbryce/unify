# %% [markdown]
# ## Count PRs created and JIRA tickets assigned per IC over last 4 months

# %% [markdown]
# **Make sure to run the 'Build Employees' notebook first to create the 'coders' view**

# %%
count github.coders
# Out:
# 1 row
#  count__
#       66

# %% [markdown]
# ### Count PRs by user over last 4 months

# %%
select
  count(*) as count, user_login
from
  github.pulls
where
  created_at > (now() - INTERVAL 4 month)
group by user_login
order by count desc
# Out:
# 109 rows
#  count            user_login
#    124              dansc0de
#     69             waegerter
#     65               dgaldon
#     64           dave-kimble
#     56               igandhi
#     55           helloimowen
#     52          brian-tatari
#     51             alexkahan
#     48           alexfraczak
#     44        lucas-baik-ttv
#     42             sevenfour
#     42                  lrod
#     41              npalombo
#     37          georgegaytan
#     36              dog-face
#     35         margot-tatari
#     33               pshelby
#     33              itsliana
#     33              seanchon
#     32             KyleZouFE
#     32       Cody123Anderson
#     31               tlovely
#     30           bobattatari
#     30              moarwick
#     30            nick-kl4us
#     29            andresgoag
#     29               ellen-x
#     29             tmoney100
#     27               nkbelow
#     27          kelly-tatari
#     27             Kyle-Dinh
#     26    rahulsharma-tatari
#     26              kyle-ttv
#     26             linda-owo
#     25         henryzhangsta
#     25       mikel-at-tatari
#     24          calvintatari
#     23         daniel-a-leon
#     23      abstractmachines
#     22         TantumNTatari
#     21         keegan-tatari
#     21        stephen-tatari
#     19               dShah81
#     18 nathaniel-sandler-ttv
#     18             Gerald-DT
#     18         BrianJFeldman
#     17               juanfec
#     16             janina213
#     16           yumeng-liao
#     14        travisd-tatari
#     14          joshua-demeo
#     14             katiesing
#     13             weitatari
#     13            vicortiz94
#     13           natanaelw67
#     13              tatar-ye
#     12            onmywayout
#     12           grigorovsky
#     12       tv-watts-tatari
#     12           brandon733t
#     10           Anna-Tatari
#     10         JamesATrevino
#      9              kienankb
#      9            leah-z-liu
#      9           turing4ever
#      9       danharristatari
#      9          tonyo-tatari
#      8             xueTatari
#      8          anushamohan7
#      8              rfarjadi
#      8            jasonjylin
#      8         willis-tatari
#      7     micahelias-tatari
#      7               glorp47
#      6          nickd-tatari
#      6                aspall
#      6        patrick-tatari
#      6       dependabot[bot]
#      5         jessicatatari
#      5                  lame
#      5        bryce-manhardt
#      4            raychung02
#      4               nzlinus
#      4               jpotth1
#      4           Jeff-tatari
#      4             byingyang
#      4       emptyset-tatari
#      4               dfinlay
#      3     computerGeologist
#      3      JimmyShao-tatari
#      3            kabirdugal
#      3          summerrr0101
#      3              sirtorry
#      2        michael-tatari
#      2           tommytatari
#      2             mattpatch
#      2           mike-tatari
#      2           manisha-pat
#      2              robkwark
#      2    keenanwells-tatari
#      2             sshirokov
#      1             sabrinaan
#      1           zwangtatari
#      1        timothydmorton
#      1             benhorntv
#      1             jkreschke
#      1   patrick-strittmater
#      1           rudy-tatari
#      1     Owen-Karpf-Tatari

# %% [markdown]
# ### Now join to 'coders' view to get employee info

# %%
with pr_counts as (
    select
      count(*) as count, user_login
    from
      github.pulls
    where
      created_at > (now() - INTERVAL 4 month)
    group by user_login
    order by count desc
)
select 
  count, user_login, name, start, lvl, manager
from 
  pr_counts
inner join
  github.coders on pr_counts.user_login = github.coders.login
# Out:
# 57 rows
#  count            user_login                name      start lvl manager
#    124              dansc0de         Dan Mahoney 2021-05-23   4   Idler
#     69             waegerter    William Aegerter 2020-11-01   5  Jeff S
#     65               dgaldon        David Galdon 2021-05-16   4   Peter
#     64           dave-kimble         Dave Kimble 2022-04-10   4     Jim
#     56               igandhi          Ike Gandhi 2019-11-10   4   Peter
#     55           helloimowen       Owen Sanders  2020-08-09   3   Scott
#     52          brian-tatari        Brian Olecki 2021-05-23   4    Reno
#     51             alexkahan          alex kahan 2022-05-31   1    Reno
#     48           alexfraczak        Alex Fraczak 2021-08-29   4    Reno
#     44        lucas-baik-ttv          Lucas Baik 2021-11-30   4    Mala
#     42             sevenfour        Leo Alekseev 2022-01-02   3   David
#     42                  lrod          Leslie Rod 2021-08-15   4 Scott P
#     41              npalombo        Nick Palombo 2021-08-31   4     Jim
#     37          georgegaytan       George Gaytan 2019-10-28   3    Reno
#     36              dog-face      noah nito vito 2020-03-08   3    Reno
#     35         margot-tatari      Margot Maxwell 2022-04-24   3   Idler
#     33               pshelby      Patrick Shelby 2020-11-08   4   Idler
#     33              itsliana       Liana Sanders 2019-10-27   3   Peter
#     33              seanchon           Sean Chon 2020-11-08   4   David
#     32             KyleZouFE            Kyle Zou 2021-08-31   2   David
#     32       Cody123Anderson       Cody Anderson 2021-04-25   4     Jim
#     31               tlovely        Tyler Lovely 2021-12-05   4     Jim
#     30           bobattatari        Bob Lockwood 2021-11-14   3   David
#     30            nick-kl4us        Nick Gentile 2021-08-08   3    Mala
#     29             tmoney100       Taylor Allred 2021-09-26   3     Jim
#     27               nkbelow          Nick Below 2019-11-03   3     Jim
#     25         henryzhangsta         Henry Zhang 2019-12-01   5   Scott
#     25       mikel-at-tatari     Michael Librodo 2016-11-14   5    Reno
#     24          calvintatari       Calvin Morrow 2021-04-25   3 Scott-I
#     23         daniel-a-leon         Daniel Leon 2021-02-28   2     Jim
#     22         TantumNTatari      Tantum Nilkaew 2022-03-14   1   David
#     21         keegan-tatari     Keegan Ferrando 2021-10-31   4   Idler
#     21        stephen-tatari       Stephen Price 2021-10-03   3  ScottI
#     19               dShah81          Dhara Shah 2022-01-09   4    Mala
#     18 nathaniel-sandler-ttv   Nathaniel Sandler 2022-03-27   3    Mala
#     18             Gerald-DT    Gerald Diep-Tran 2022-01-23   3     Jim
#     18         BrianJFeldman       Brian Feldman 2018-09-04   4    Mala
#     16             janina213        Janina Mejia 2019-01-06   3     Jim
#     14        travisd-tatari        Travis Doane 2021-10-17   3    Reno
#     14             katiesing          Katie Sing 2021-06-06   2    Mala
#     12           brandon733t         Brandon Lee 2021-08-15   4  Jeff S
#     10         JamesATrevino       James Trevino 2022-01-02   3     Jim
#      9            leah-z-liu            Leah Liu 2021-03-21   2   Bruce
#      9           turing4ever             Yi Wang 2020-10-18   4     Jim
#      9          tonyo-tatari         Tony O'Dell 2022-07-31   4    Reno
#      8              rfarjadi        Ryan Farjadi 2017-07-09   5   Scott
#      8         willis-tatari     Willis Schubert 2022-04-10   1   Idler
#      5                  lame           Ryan Kuhl 2018-11-25   4  Jeff S
#      4            raychung02           Ray Chung 2021-01-17   2  Barone
#      4               jpotth1     Jordan Potthoff 2021-06-13   4   Bruce
#      4             byingyang         Brad Yinger 2020-10-05   4  Jeff S
#      4       emptyset-tatari            Alan Fay 2021-04-25   4   David
#      3              sirtorry          Torry Yang 2022-03-27   2    Mala
#      2           mike-tatari        Mike Bartoli 2022-05-01   4    Jeff
#      2    keenanwells-tatari        Keenan Wells 2022-06-26   3    Reno
#      1             benhorntv   Ben Horn @ Tatari 2021-05-23   2   Scott
#      1   patrick-strittmater Patrick Strittmater 2021-05-23   4   Scott

# %% [markdown]
# ### Now count JIRA tickets by person

# %%
  select 
     count(*) as count, assignee_displayName
  from 
     jira.issues
  where created > (now() - interval 4 month)
  group by assignee_displayName
  order by count desc
# Out:
# 184 rows
#  count    assignee_displayName
#   1607
#    370           Manisha Patel
#    132         Bruce Rechichar
#    127             Jervin Cruz
#    103              Rifat Khan
#    100       Vitalii Litkevich
#     85            Victor Ortiz
#     82            Anusha Mohan
#     80           Solomon Klein
#     76      Viacheslav Shostak
#     71             Tommy Hogan
#     69              Ellen Xiao
#     69      Vasily Grigorovsky
#     69           Michael Smith
#     68             Jessica Cai
#     67       Alessandro Gracia
#     65          Abdullah Spall
#     65            David Galdon
#     64              Josh Demeo
#     63          Thuy-Van Watts
#     61                 Xue Gao
#     60              Sabrina An
#     59                Leah Liu
#     58               Matt Agin
#     57              Anna Young
#     57                Will Vea
#     57                Jeff Cai
#     56            Leo Alekseev
#     56              Matt Patch
#     55              Ike Gandhi
#     53               Rob Kwark
#     53               Ray Chung
#     52        William Aegerter
#     51            Kyle Kosnoff
#     48          Bryce Manhardt
#     47           Stephen Price
#     46           Dmitriy Butko
#     46 Nataliia Myroshnychenko
#     46         Willis Schubert
#     46           Cody Anderson
#     45             Kabir Dugal
#     45          Patrick Shelby
#     44              Alex Kahan
#     44            Tyler Lovely
#     42             Dan Mahoney
#     41             Stan Kudrow
#     41           Calvin Morrow
#     39          Yevhen Shakhov
#     38            Yana Belokoz
#     38           George Gaytan
#     37                Ben Horn
#     37                  Ada Li
#     37     Alexandre Dieudonne
#     37           Dan Stynchula
#     34        Roman Pavlushkov
#     34         Majken Longlade
#     33            Nick Palombo
#     32            David Kimble
#     32            Owen Sanders
#     32           Liana Sanders
#     32            Mike Swinson
#     32            Rudy Gilmore
#     30            Amanda Falke
#     30      Jeremy Glenn Lopez
#     29         Jordan Potthoff
#     28              Zishu Wang
#     28              Lucas Baik
#     28               Brian Sam
#     27            Bob Lockwood
#     27              Owen Karpf
#     27              Nick Below
#     27            Nick Gentile
#     26            Jake Reschke
#     26            Jaeyeong Kim
#     25            Brian Olecki
#     25                Kyle Zou
#     25          Polina Frolova
#     24          Margot Maxwell
#     24         Keegan Ferrando
#     24            Janina Mejia
#     23           Brian Feldman
#     23               Noah Vito
#     23          Tantum Nilkaew
#     23           Russell Simco
#     23 Leslie Rodriguez Garcia
#     23          Peter Morawiec
#     23              Katie Sing
#     23               Summer Ye
#     22               Sean Chon
#     22            Alex Fraczak
#     22                 Yi Wang
#     21           Taylor Allred
#     21            Travis Doane
#     21        Anton Slobodskyi
#     21               JP Ciceri
#     21              Juan Rueda
#     21            Oleg Gubanov
#     20               Kyle Dinh
#     20              Tim Morton
#     20       Nathaniel Sandler
#     19     Patrick Strittmater
#     18    Andres Gomez Agudelo
#     18                Wei Chen
#     18            Lucas Miller
#     18             Daniel Leon
#     18                 Jian Lu
#     17    Clara Martinez Rubio
#     16           Haris Qureshi
#     16              Dhara Shah
#     15                Toni Poe
#     13         Kaitlin Rasborn
#     12              Jim Lyndon
#     12           Mala Munisamy
#     12             Maxwell Guo
#     12     Kienan Knight-Boehm
#     11           James Trevino
#     11     Gennadii Kravchenko
#     11             Brandon Lee
#     11              Andrew Kim
#     11             Sakshi Garg
#     11             Henry Zhang
#     10              Linda Wang
#     10                Ty McRae
#     10        Gerald Diep-Tran
#     10           Daniel Harris
#      9         Natanael Wijaya
#      9               Ryan Kuhl
#      9            Simran Patil
#      9             Yumeng Liao
#      9              Patrick He
#      9             Brent White
#      9            Rahul Sharma
#      8            Mike Librodo
#      8              Torry Yang
#      8         Elizabeth Spear
#      7              Vlad Belik
#      7          Nicolas Zapata
#      7              Jimmy Shao
#      7            Truxten Cook
#      7      Michael Collington
#      7          Mfon Afangideh
#      7               Jason Lin
#      7             Kelly Chung
#      7             Tony O'Dell
#      7          Artem Bukariev
#      6             Micah Elias
#      6              Nick Davis
#      6          Tyrone Chouhan
#      5           Farbod Safaei
#      5               David Hwu
#      5             Tim Gumbley
#      5             Brad Yinger
#      4           Puneet Nayyar
#      4                Annie Xu
#      4              Reno Brown
#      4            Ryan Farjadi
#      4             Dave Finlay
#      4              Mike Child
#      3            Mike Bartoli
#      2             Charlie Qin
#      2                 Gary Ye
#      2            Yulia Koshel
#      2             Scott Idler
#      2          Lin O'Driscoll
#      2            Keenan Wells
#      2            Ani Govindan
#      2          Slava Shirokov
#      1           Russ O'Reagan
#      1            Jerome Banks
#      1         Scott Persinger
#      1         Aaron Perlstein
#      1              Caleb Rouw
#      1           Harshal Dalvi
#      1            Dima Dibrova
#      1              Max Zaydes
#      1      Andrew Prysiazhnyi
#      1              Jeff Stamm
#      1               Jena Vint
#      1          Leo Perenzuela
#      1           Yana Kyselova
#      1        Erika Clingerman
#      1                Alan Fay
#      1          Matt Giannetti
#      1           Lizzie Sandie

# %% [markdown]
# ### Now query both JIRA issues and PR counts together into a view

# %%
create or replace view github.prs_and_tickets as (
    with jira_issues as (
      select 
         count(*) as count, assignee_displayName as name
      from 
         jira.issues
      where created > (now() - interval 4 month)
      group by assignee_displayName
      order by count desc
    ),
    pr_counts as (
        select
          count(*) as count, user_login
        from
          github.pulls
        where
          created_at > (now() - INTERVAL 4 month)
        group by user_login
        order by count desc
    )
    select 
      user_login, github.coders.name, start, lvl, manager, pr_counts.count as prs, jira_issues.count as tickets
    from 
      pr_counts
    inner join
      github.coders on pr_counts.user_login = github.coders.login
    join
      jira_issues on ltrim(rtrim(lower(github.coders.name))) = ltrim(rtrim(lower(jira_issues.name)))
    order by (pr_counts.count + jira_issues.count) desc
)
# Out:
# 0 rows
# Empty DataFrame
# Columns: []
# Index: []

# %%
select * from github.prs_and_tickets
# Out:
# 52 rows
#            user_login tenant_scottp_github____coders_name      start lvl manager  prs  tickets
#              dansc0de                         Dan Mahoney 2021-05-23   4   Idler  124       42
#               dgaldon                        David Galdon 2021-05-16   4   Peter   65       65
#             waegerter                    William Aegerter 2020-11-01   5  Jeff S   69       52
#               igandhi                          Ike Gandhi 2019-11-10   4   Peter   56       55
#             sevenfour                        Leo Alekseev 2022-01-02   3   David   42       56
#             alexkahan                          alex kahan 2022-05-31   1    Reno   51       44
#           helloimowen                       Owen Sanders  2020-08-09   3   Scott   55       32
#               pshelby                      Patrick Shelby 2020-11-08   4   Idler   33       45
#       Cody123Anderson                       Cody Anderson 2021-04-25   4     Jim   32       46
#          brian-tatari                        Brian Olecki 2021-05-23   4    Reno   52       25
#               tlovely                        Tyler Lovely 2021-12-05   4     Jim   31       44
#          georgegaytan                       George Gaytan 2019-10-28   3    Reno   37       38
#              npalombo                        Nick Palombo 2021-08-31   4     Jim   41       33
#        lucas-baik-ttv                          Lucas Baik 2021-11-30   4    Mala   44       28
#           alexfraczak                        Alex Fraczak 2021-08-29   4    Reno   48       22
#        stephen-tatari                       Stephen Price 2021-10-03   3  ScottI   21       47
#            leah-z-liu                            Leah Liu 2021-03-21   2   Bruce    9       59
#              itsliana                       Liana Sanders 2019-10-27   3   Peter   33       32
#          calvintatari                       Calvin Morrow 2021-04-25   3 Scott-I   24       41
#         margot-tatari                      Margot Maxwell 2022-04-24   3   Idler   35       24
#             KyleZouFE                            Kyle Zou 2021-08-31   2   David   32       25
#           bobattatari                        Bob Lockwood 2021-11-14   3   David   30       27
#            raychung02                           Ray Chung 2021-01-17   2  Barone    4       53
#            nick-kl4us                        Nick Gentile 2021-08-08   3    Mala   30       27
#              seanchon                           Sean Chon 2020-11-08   4   David   33       22
#         willis-tatari                     Willis Schubert 2022-04-10   1   Idler    8       46
#               nkbelow                          Nick Below 2019-11-03   3     Jim   27       27
#             tmoney100                       Taylor Allred 2021-09-26   3     Jim   29       21
#         keegan-tatari                     Keegan Ferrando 2021-10-31   4   Idler   21       24
#         TantumNTatari                      Tantum Nilkaew 2022-03-14   1   David   22       23
#         BrianJFeldman                       Brian Feldman 2018-09-04   4    Mala   18       23
#         daniel-a-leon                         Daniel Leon 2021-02-28   2     Jim   23       18
#             janina213                        Janina Mejia 2019-01-06   3     Jim   16       24
# nathaniel-sandler-ttv                   Nathaniel Sandler 2022-03-27   3    Mala   18       20
#             katiesing                          Katie Sing 2021-06-06   2    Mala   14       23
#         henryzhangsta                         Henry Zhang 2019-12-01   5   Scott   25       11
#        travisd-tatari                        Travis Doane 2021-10-17   3    Reno   14       21
#               dShah81                          Dhara Shah 2022-01-09   4    Mala   19       16
#               jpotth1                     Jordan Potthoff 2021-06-13   4   Bruce    4       29
#           turing4ever                             Yi Wang 2020-10-18   4     Jim    9       22
#             Gerald-DT                    Gerald Diep-Tran 2022-01-23   3     Jim   18       10
#           brandon733t                         Brandon Lee 2021-08-15   4  Jeff S   12       11
#         JamesATrevino                       James Trevino 2022-01-02   3     Jim   10       11
#   patrick-strittmater                 Patrick Strittmater 2021-05-23   4   Scott    1       19
#          tonyo-tatari                         Tony O'Dell 2022-07-31   4    Reno    9        7
#                  lame                           Ryan Kuhl 2018-11-25   4  Jeff S    5        9
#              rfarjadi                        Ryan Farjadi 2017-07-09   5   Scott    8        4
#              sirtorry                          Torry Yang 2022-03-27   2    Mala    3        8
#             byingyang                         Brad Yinger 2020-10-05   4  Jeff S    4        5
#           mike-tatari                        Mike Bartoli 2022-05-01   4    Jeff    2        3
#       emptyset-tatari                            Alan Fay 2021-04-25   4   David    4        1
#    keenanwells-tatari                        Keenan Wells 2022-06-26   3    Reno    2        2

# %% [markdown]
# ### And now export the view to Google Sheets

# %%
$name='PRs and Ticket stats - ' || cast(date_trunc('day',now()) as varchar)
# Out:
# PRs and Ticket stats - 2022-10-12 00:00:00

# %%
$name
# Out:
# PRs and Ticket stats - 2022-10-12 00:00:00

# %%
export github.prs_and_tickets to gsheets $name overwrite
# Out:
# Wrote 53 rows to sheet
# Exported query result to 'PRs and Ticket stats - 2022-10-12 00:00:00'

# %%
email github.prs_and_tickets to 'scottp@berkeleyzone.net'
# Out:
# Emailing github.prs_and_tickets to ['scottp@berkeleyzone.net']

# %%
export github.prs_and_tickets to 'ic_stats.xlsx'
# Out:
# Exported query result to 'ic_stats.xlsx'
