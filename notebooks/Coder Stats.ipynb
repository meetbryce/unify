# %% [markdown]
# ## Count PRs created and JIRA tickets assigned per IC over last 4 months

# %% [markdown]
# **Make sure to run the 'Build Employees' notebook first to create the 'coders' view**

# %%
count github.coders
# Out:
# Table github.coders does not exist

# %% [markdown]
# ### Count PRs by user over last 4 months

# %%
select
  count(*) as count, user_login
from
  github.pulls
where
  created_at > (current_date - INTERVAL 4 month)
group by user_login
order by count desc
# Out:
# 123 rows
#  count            user_login
#    265              dansc0de
#    183        stephen-tatari
#    156   patrick-strittmater
#    125               pshelby
#    119          calvintatari
#     90         margot-tatari
#     78             katiesing
#     75         henryzhangsta
#     75           helloimowen
#     74           jeromebanks
#     69             benhorntv
#     69        rsty-instgrmpy
#     68               nkbelow
#     65           dave-kimble
#     63          brian-tatari
#     63           bobattatari
#     61             Gerald-DT
#     60         keegan-tatari
#     59              npalombo
#     58               dgaldon
#     57         truongluan303
#     56             linda-owo
#     56           brandon733t
#     52              itsliana
#     51             alexkahan
#     51              tatar-ye
#     50           turing4ever
#     49               ellen-x
#     48             KyleZouFE
#     46             waegerter
#     46               igandhi
#     45        lucas-baik-ttv
#     43               tlovely
#     42             sevenfour
#     40       Cody123Anderson
#     39    truxtencook-tatari
#     37           alexfraczak
#     35          georgegaytan
#     35            nick-kl4us
#     35         JamesATrevino
#     35              sirtorry
#     35                  lrod
#     34                  lame
#     34         escote-tatari
#     33              dog-face
#     33             Kyle-Dinh
#     33              kyle-ttv
#     32             tmoney100
#     32          joshua-demeo
#     32               jglopez
#     30        timothydmorton
#     29             janina213
#     28           mike-tatari
#     28           simranpatil
#     27         daniel-a-leon
#     27           yumeng-liao
#     26    rahulsharma-tatari
#     23         TantumNTatari
#     22          kelly-tatari
#     22            vicortiz94
#     22        claramartinez2
#     21            andresgoag
#     21      abstractmachines
#     19              moarwick
#     19             weitatari
#     18              seanchon
#     18            jasonjylin
#     18             byingyang
#     17 nathaniel-sandler-ttv
#     17         BrianJFeldman
#     17         jessicatatari
#     16              kienankb
#     16         sakshi-tatari
#     15             Jaykim148
#     14             sabrinaan
#     14         willis-tatari
#     13               juanfec
#     13             mattpatch
#     13           tommytatari
#     12       danharristatari
#     12             sshirokov
#     12              robkwark
#     12          anushamohan7
#     11       mikel-at-tatari
#     11     micahelias-tatari
#     11          jianattatari
#     11             xueTatari
#     10             tkohrumel
#      9       dependabot[bot]
#      9              rfarjadi
#      9        travisd-tatari
#      9       tv-watts-tatari
#      8           natanaelw67
#      8     computerGeologist
#      8                aspall
#      7            leah-z-liu
#      7           grigorovsky
#      7           tataristaku
#      7          nickd-tatari
#      6       emptyset-tatari
#      6               jpotth1
#      6        bryce-manhardt
#      6            brechichar
#      6              will-vea
#      5            raychung02
#      5               glorp47
#      5          summerrr0101
#      4            onmywayout
#      4               dShah81
#      4            kabirdugal
#      4           rudy-tatari
#      4             ajwhitley
#      4             spindle79
#      4             jkreschke
#      3               dfinlay
#      3                jeffcs
#      3           Mfon-tatari
#      2            JJJ-Tatari
#      2               nzlinus
#      2             jp-tatari
#      1    keenanwells-tatari
#      1          childmike222
#      1 congcharlieqin-tatari

# %% [markdown]
# ### Now join to 'coders' view to get employee info

# %%
with pr_counts as (
    select
      count(*) as count, user_login
    from
      github.pulls
    where
      created_at > (current_date - INTERVAL 4 month)
    group by user_login
    order by count desc
)
select 
  count, user_login, name, start, level, manager
from 
  pr_counts
inner join
  github.coders on pr_counts.user_login = github.coders.login
# Out:
# 71 rows
#  count            user_login                 name      start  level manager
#    265              dansc0de          Dan Mahoney 2021-05-24      4   Idler
#    183        stephen-tatari        Stephen Price 2021-10-04      3  ScottI
#    156   patrick-strittmater  Patrick Strittmater 2021-05-24      4   Scott
#    125               pshelby       Patrick Shelby 2020-11-09      4   Idler
#    119          calvintatari        Calvin Morrow 2021-04-26      3 Scott-I
#     90         margot-tatari       Margot Maxwell 2022-04-25      3   Idler
#     78             katiesing           Katie Sing 2021-06-07      2    Mala
#     75         henryzhangsta          Henry Zhang 2019-12-02      5   Scott
#     75           helloimowen        Owen Sanders  2020-08-10      3   Scott
#     74           jeromebanks         Jerome Banks 2021-01-18      5   Scott
#     69             benhorntv    Ben Horn @ Tatari 2021-05-24      2   Scott
#     69        rsty-instgrmpy        Russell Simco 2021-06-28      3   Scott
#     68               nkbelow       Nicholas Below 2019-11-04      3     Jim
#     65           dave-kimble          Dave Kimble 2022-04-11      4     Jim
#     63          brian-tatari         Brian Olecki 2021-05-24      4    Reno
#     63           bobattatari         Bob Lockwood 2021-11-15      3   David
#     61             Gerald-DT     Gerald Diep-Tran 2022-01-24      3     Jim
#     60         keegan-tatari      Keegan Ferrando 2021-11-01      4   Idler
#     59              npalombo         Nick Palombo 2021-09-01      4     Jim
#     58               dgaldon         David Galdon 2021-05-17      4   Peter
#     56             linda-owo           linda wang 2022-02-07      3     Jim
#     56           brandon733t          Brandon Lee 2021-08-16      4  Jeff S
#     52              itsliana        Liana Sanders 2019-10-28      3   Peter
#     51             alexkahan           alex kahan 2022-06-01      1    Reno
#     50           turing4ever              Yi Wang 2020-10-19      4     Jim
#     48             KyleZouFE             Kyle Zou 2021-09-01      2   David
#     46             waegerter     William Aegerter 2020-11-02      5  Jeff S
#     46               igandhi           Ike Gandhi 2019-11-11      4   Peter
#     45        lucas-baik-ttv           Lucas Baik 2021-12-01      4    Mala
#     43               tlovely         Tyler Lovely 2021-12-06      4     Jim
#     42             sevenfour         Leo Alekseev 2022-01-03      3   David
#     40       Cody123Anderson        Cody Anderson 2021-04-26      4     Jim
#     37           alexfraczak         Alex Fraczak 2021-08-30      4    Reno
#     35          georgegaytan        George Gaytan 2019-10-29      3    Reno
#     35            nick-kl4us         Nick Gentile 2021-08-09      3    Mala
#     35         JamesATrevino        James Trevino 2022-01-03      3     Jim
#     35              sirtorry           Torry Yang 2022-03-28      2    Mala
#     35                  lrod           Leslie Rod 2021-08-16      4 Scott P
#     34                  lame            Ryan Kuhl 2018-11-26      4  Jeff S
#     33              dog-face       noah nito vito 2020-03-09      3    Reno
#     32             tmoney100        Taylor Allred 2021-09-27      3     Jim
#     32               jglopez   Jeremy Glenn Lopez 2021-05-24      2 Scott-I
#     29             janina213         Janina Mejia 2019-01-07      3     Jim
#     28           mike-tatari         Mike Bartoli 2022-05-02      4    Jeff
#     27         daniel-a-leon          Daniel Leon 2021-03-01      2     Jim
#     27           yumeng-liao          Yumeng Liao 2021-03-22      2   Peter
#     23         TantumNTatari       Tantum Nilkaew 2022-03-15      1   David
#     22        claramartinez2 Clara Martinez Rubio 2022-04-18      3    Mala
#     21      abstractmachines         Amanda Falke 2021-12-07      3   Peter
#     18              seanchon            Sean Chon 2020-11-09      4   David
#     18             byingyang          Brad Yinger 2020-10-06      4  Jeff S
#     17 nathaniel-sandler-ttv    Nathaniel Sandler 2022-03-28      3    Mala
#     17         BrianJFeldman        Brian Feldman 2018-09-05      4    Mala
#     16              kienankb  kienan knight-boehm 2020-11-09      2   David
#     14         willis-tatari      Willis Schubert 2022-04-11      1   Idler
#     12             sshirokov       Slava Shirokov 2021-01-11      4     Jim
#     11       mikel-at-tatari      Michael Librodo 2016-11-15      5    Reno
#      9              rfarjadi         Ryan Farjadi 2017-07-10      5   Scott
#      9        travisd-tatari         Travis Doane 2021-10-18      3    Reno
#      7            leah-z-liu             Leah Liu 2021-03-22      2   Bruce
#      7           tataristaku          Stan Kudrow 2022-06-27      4 Harshal
#      7          nickd-tatari           Nick Davis 2022-05-02      3     Jim
#      6       emptyset-tatari             Alan Fay 2021-04-26      4   David
#      6               jpotth1      Jordan Potthoff 2021-06-14      4   Bruce
#      6              will-vea          William Vea 2022-02-14      2   Bruce
#      5            raychung02            Ray Chung 2021-01-18      2  Barone
#      5               glorp47        Haris Qureshi 2021-05-10      3    Mala
#      4               dShah81           Dhara Shah 2022-01-10      4    Mala
#      3               dfinlay          Dave Finlay 2021-05-17      4    Mala
#      2             jp-tatari            JP Ciceri 2021-12-07      2   Dan S
#      1    keenanwells-tatari         Keenan Wells 2022-06-27      3    Reno

# %% [markdown]
# ### Now count JIRA tickets by person

# %%
  select 
     count(*) as count, fields_assignee_displayName
  from 
     jira.issues
  where fields_created > (current_date - interval 4 month)
  group by all
  order by count desc
# Out:
# 181 rows
#  count fields_assignee_displayName
#   1162                         NaN
#    215               Manisha Patel
#    198                  Rifat Khan
#    121           Vitalii Litkevich
#    119             Bruce Rechichar
#     86                Anusha Mohan
#     85               Solomon Klein
#     85                Victor Ortiz
#     84               Michael Smith
#     81          Viacheslav Shostak
#     79                   Ray Chung
#     79                 Kabir Dugal
#     78                 Jervin Cruz
#     77                    Will Vea
#     71                 Jessica Cai
#     71                    Leah Liu
#     70                   Rob Kwark
#     69                  Ellen Xiao
#     68                  Josh Demeo
#     66          Vasily Grigorovsky
#     65              Abdullah Spall
#     62              Bryce Manhardt
#     62                Oleg Gubanov
#     59             Jordan Potthoff
#     57                  Sabrina An
#     54             Majken Longlade
#     53                  Matt Patch
#     52               Calvin Morrow
#     51              Yevhen Shakhov
#     48                 Tommy Hogan
#     48                David Galdon
#     48                   Matt Agin
#     47                  Ike Gandhi
#     46           Alessandro Gracia
#     46     Nataliia Myroshnychenko
#     44                Leo Alekseev
#     43                  Tim Morton
#     42                Bob Lockwood
#     42                 Dan Mahoney
#     41               Stephen Price
#     40         Alexandre Dieudonne
#     40                     Xue Gao
#     40                Yana Belokoz
#     39                Kyle Kosnoff
#     38                      Ada Li
#     37          Jeremy Glenn Lopez
#     36               Dmitriy Butko
#     35                Tyler Lovely
#     35               Brian Feldman
#     35               Liana Sanders
#     35               Taylor Allred
#     34                  Owen Karpf
#     34              Thuy-Van Watts
#     33                Rudy Gilmore
#     33                Mike Swinson
#     32                  Alex Kahan
#     31              Patrick Shelby
#     31            William Aegerter
#     31                   Noah Vito
#     30            Roman Pavlushkov
#     30             Keegan Ferrando
#     29                   Summer Ye
#     29                Jaeyeong Kim
#     28               George Gaytan
#     28             Willis Schubert
#     27                  Lucas Baik
#     27                  Mike Child
#     27                    Wei Chen
#     26                Amanda Falke
#     26                    Kyle Zou
#     25                Nick Gentile
#     25                    Ben Horn
#     25     Leslie Rodriguez Garcia
#     24                  Zishu Wang
#     24                Nick Palombo
#     24              Margot Maxwell
#     24                Brian Olecki
#     23               Mala Munisamy
#     23                Owen Sanders
#     23             Kaitlin Rasborn
#     22                     Yi Wang
#     22               Cody Anderson
#     22                 Yumeng Liao
#     22                Travis Doane
#     22                   Brian Sam
#     21                    Toni Poe
#     21              Polina Frolova
#     21               Dan Stynchula
#     20              Tantum Nilkaew
#     20            Gerald Diep-Tran
#     19                   JP Ciceri
#     19               James Trevino
#     18              Peter Morawiec
#     18               Farbod Safaei
#     18                David Kimble
#     18                   Ryan Kuhl
#     18                Jake Reschke
#     17               Russell Simco
#     17        Andres Gomez Agudelo
#     16                   Jason Lin
#     15                  Katie Sing
#     15                   Kyle Dinh
#     14                 Brent White
#     14                  Linda Wang
#     14                 Henry Zhang
#     14                   Sean Chon
#     14         Kienan Knight-Boehm
#     14                Simran Patil
#     13                Lucas Miller
#     13               Haris Qureshi
#     13                  Anna Young
#     13                Mike Librodo
#     13                Rahul Sharma
#     13                  Nick Below
#     12                  Nick Davis
#     12                    Jeff Cai
#     12                 Maxwell Guo
#     12                 Daniel Leon
#     12               Daniel Harris
#     12                 Sakshi Garg
#     12                Tim Kohrumel
#     11                Janina Mejia
#     11              Slava Shirokov
#     10                 Brandon Lee
#     10                     Jian Lu
#     10                    Annie Xu
#      9         Patrick Strittmater
#      9           Nathaniel Sandler
#      9                  Juan Rueda
#      9                 Brad Yinger
#      8                     Gary Ye
#      8            Anton Slobodskyi
#      8                Alex Fraczak
#      8             Natanael Wijaya
#      8                Jerome Banks
#      7                Ryan Farjadi
#      7                  Jim Lyndon
#      7                  Jimmy Shao
#      7              Tyrone Chouhan
#      7                  Dhara Shah
#      7                 Kelly Chung
#      7                 Luan Truong
#      6                  Torry Yang
#      6         Gennadii Kravchenko
#      6             Elizabeth Spear
#      6              Nicolas Zapata
#      6        Clara Martinez Rubio
#      5                 Dave Finlay
#      4                 Tim Gumbley
#      4                 Micah Elias
#      4                Mike Bartoli
#      4                 Scott Idler
#      4                    Ty McRae
#      4              Lin O'Driscoll
#      4                    Alan Fay
#      3                 Stan Kudrow
#      3                   David Hwu
#      3               Russ O'Reagan
#      3                  Reno Brown
#      2              Mfon Afangideh
#      2                Keenan Wells
#      2              Alex Markaryan
#      1                  Andrew Kim
#      1                   Jena Vint
#      1                 Charlie Qin
#      1              Matt Giannetti
#      1              Leo Perenzuela
#      1                Truxten Cook
#      1                  Max Zaydes
#      1             Scott Persinger
#      1               Lizzie Sandie
#      1                 Yarik Vyrva
#      1             Theresa Amrhein
#      1               Harshal Dalvi
#      1                  Vlad Belik
#      1                    Julia Wu
#      1                Jinjin Jiang
#      1              Kevin Thompson
#      1                Meagan Boggs
#      1          Michael Collington
#      1             Aaron Perlstein

# %% [markdown]
# ### Now query both JIRA issues and PR counts together into a view

# %%
create or replace view github.prs_and_tickets as (
    with jira_issues as (
      select 
         count(*) as count, fields_assignee_displayName as name
      from 
         jira.issues
      where fields_created > (current_date - interval 4 month)
      group by all
      order by count desc
    ),
    pr_counts as (
        select
          count(*) as count, user_login
        from
          github.pulls
        where
          created_at > (current_date - INTERVAL 4 month)
        group by user_login
        order by count desc
    )
    select 
      user_login, coders.name, start, level, manager, pr_counts.count as prs, jira_issues.count as tickets
    from 
      pr_counts
    inner join
      github.coders on pr_counts.user_login = github.coders.login
    join
      jira_issues on ltrim(rtrim(lower(github.coders.name))) = ltrim(rtrim(lower(jira_issues.name)))
    order by (pr_counts.count + jira_issues.count) desc
)
# Out:
# 0 rows
# Empty DataFrame
# Columns: [Count]
# Index: []

# %%
select * from github.prs_and_tickets
# Out:
# 64 rows
#            user_login                 name      start  level manager  prs  tickets
#              dansc0de          Dan Mahoney 2021-05-24      4   Idler  265       42
#        stephen-tatari        Stephen Price 2021-10-04      3  ScottI  183       41
#          calvintatari        Calvin Morrow 2021-04-26      3 Scott-I  119       52
#   patrick-strittmater  Patrick Strittmater 2021-05-24      4   Scott  156        9
#               pshelby       Patrick Shelby 2020-11-09      4   Idler  125       31
#         margot-tatari       Margot Maxwell 2022-04-25      3   Idler   90       24
#               dgaldon         David Galdon 2021-05-17      4   Peter   58       48
#           bobattatari         Bob Lockwood 2021-11-15      3   David   63       42
#           helloimowen        Owen Sanders  2020-08-10      3   Scott   75       23
#             katiesing           Katie Sing 2021-06-07      2    Mala   78       15
#               igandhi           Ike Gandhi 2019-11-11      4   Peter   46       47
#         keegan-tatari      Keegan Ferrando 2021-11-01      4   Idler   60       30
#         henryzhangsta          Henry Zhang 2019-12-02      5   Scott   75       14
#          brian-tatari         Brian Olecki 2021-05-24      4    Reno   63       24
#              itsliana        Liana Sanders 2019-10-28      3   Peter   52       35
#        rsty-instgrmpy        Russell Simco 2021-06-28      3   Scott   69       17
#             sevenfour         Leo Alekseev 2022-01-03      3   David   42       44
#            raychung02            Ray Chung 2021-01-18      2  Barone    5       79
#              npalombo         Nick Palombo 2021-09-01      4     Jim   59       24
#             alexkahan           alex kahan 2022-06-01      1    Reno   51       32
#           jeromebanks         Jerome Banks 2021-01-18      5   Scott   74        8
#             Gerald-DT     Gerald Diep-Tran 2022-01-24      3     Jim   61       20
#               tlovely         Tyler Lovely 2021-12-06      4     Jim   43       35
#            leah-z-liu             Leah Liu 2021-03-22      2   Bruce    7       71
#             waegerter     William Aegerter 2020-11-02      5  Jeff S   46       31
#             KyleZouFE             Kyle Zou 2021-09-01      2   David   48       26
#           turing4ever              Yi Wang 2020-10-19      4     Jim   50       22
#        lucas-baik-ttv           Lucas Baik 2021-12-01      4    Mala   45       27
#             linda-owo           linda wang 2022-02-07      3     Jim   56       14
#               jglopez   Jeremy Glenn Lopez 2021-05-24      2 Scott-I   32       37
#             tmoney100        Taylor Allred 2021-09-27      3     Jim   32       35
#           brandon733t          Brandon Lee 2021-08-16      4  Jeff S   56       10
#               jpotth1      Jordan Potthoff 2021-06-14      4   Bruce    6       59
#          georgegaytan        George Gaytan 2019-10-29      3    Reno   35       28
#       Cody123Anderson        Cody Anderson 2021-04-26      4     Jim   40       22
#            nick-kl4us         Nick Gentile 2021-08-09      3    Mala   35       25
#         JamesATrevino        James Trevino 2022-01-03      3     Jim   35       19
#                  lame            Ryan Kuhl 2018-11-26      4  Jeff S   34       18
#         BrianJFeldman        Brian Feldman 2018-09-05      4    Mala   17       35
#           yumeng-liao          Yumeng Liao 2021-03-22      2   Peter   27       22
#      abstractmachines         Amanda Falke 2021-12-07      3   Peter   21       26
#           alexfraczak         Alex Fraczak 2021-08-30      4    Reno   37        8
#         TantumNTatari       Tantum Nilkaew 2022-03-15      1   David   23       20
#         willis-tatari      Willis Schubert 2022-04-11      1   Idler   14       28
#              sirtorry           Torry Yang 2022-03-28      2    Mala   35        6
#             janina213         Janina Mejia 2019-01-07      3     Jim   29       11
#         daniel-a-leon          Daniel Leon 2021-03-01      2     Jim   27       12
#           mike-tatari         Mike Bartoli 2022-05-02      4    Jeff   28        4
#              seanchon            Sean Chon 2020-11-09      4   David   18       14
#        travisd-tatari         Travis Doane 2021-10-18      3    Reno    9       22
#              kienankb  kienan knight-boehm 2020-11-09      2   David   16       14
#        claramartinez2 Clara Martinez Rubio 2022-04-18      3    Mala   22        6
#             byingyang          Brad Yinger 2020-10-06      4  Jeff S   18        9
# nathaniel-sandler-ttv    Nathaniel Sandler 2022-03-28      3    Mala   17        9
#             sshirokov       Slava Shirokov 2021-01-11      4     Jim   12       11
#             jp-tatari            JP Ciceri 2021-12-07      2   Dan S    2       19
#          nickd-tatari           Nick Davis 2022-05-02      3     Jim    7       12
#               glorp47        Haris Qureshi 2021-05-10      3    Mala    5       13
#              rfarjadi         Ryan Farjadi 2017-07-10      5   Scott    9        7
#               dShah81           Dhara Shah 2022-01-10      4    Mala    4        7
#           tataristaku          Stan Kudrow 2022-06-27      4 Harshal    7        3
#       emptyset-tatari             Alan Fay 2021-04-26      4   David    6        4
#               dfinlay          Dave Finlay 2021-05-17      4    Mala    3        5
#    keenanwells-tatari         Keenan Wells 2022-06-27      3    Reno    1        2

# %% [markdown]
# ### And now export the view to Google Sheets

# %%
export github.prs_and_tickets to gsheets ('PRs and Ticket stats - ' || current_date) overwrite
# Out:
# Wrote 64 rows to sheet
# Exported query result to 'PRs and Ticket stats - 2022-08-03'

# %%
email github.prs_and_tickets to 'scottp@berkeleyzone.net'
# Out:
# Emailing github.prs_and_tickets to ['scottp@berkeleyzone.net']
