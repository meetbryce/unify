# %% [markdown]
# ## Count PRs created and JIRA tickets assigned per IC over last 4 months

# %% [markdown]
# **Make sure to run the 'Build Employees' notebook first to create the 'coders' view**

# %%
count github.coders
# Out:
# 1 row
#  count
#     73

# %% [markdown]
# ### Count PRs by user over last 4 months

# %%
select
  count(*) as count, user_login
from
  github.pulls
where
  created_at > (current_date - INTERVAL 4 month)
group by user_login
order by count desc
# Out:
# 124 rows
#  count            user_login
#    281              dansc0de
#    192        stephen-tatari
#    133               pshelby
#    133   patrick-strittmater
#    118          calvintatari
#    114         henryzhangsta
#    103           helloimowen
#     96             Gerald-DT
#     89           jeromebanks
#     87         margot-tatari
#     86        rsty-instgrmpy
#     80             linda-owo
#     79             katiesing
#     72         truongluan303
#     71           brandon733t
#     70                  lame
#     64          brian-tatari
#     63           dave-kimble
#     60             benhorntv
#     59               nkbelow
#     58         keegan-tatari
#     57           turing4ever
#     54               dgaldon
#     54           bobattatari
#     54             KyleZouFE
#     52              itsliana
#     52               ellen-x
#     51              tatar-ye
#     45              npalombo
#     43        lucas-baik-ttv
#     43             sevenfour
#     42            nick-kl4us
#     41               igandhi
#     41       Cody123Anderson
#     40             alexkahan
#     38           alexfraczak
#     38        timothydmorton
#     38         escote-tatari
#     36         JamesATrevino
#     36               tlovely
#     36    truxtencook-tatari
#     35             waegerter
#     35          joshua-demeo
#     33              dog-face
#     32              sirtorry
#     32              kyle-ttv
#     30             Kyle-Dinh
#     30                  lrod
#     29           yumeng-liao
#     29             tmoney100
#     29               jglopez
#     28             weitatari
#     26         daniel-a-leon
#     25             janina213
#     24          georgegaytan
#     23    rahulsharma-tatari
#     23            vicortiz94
#     21      abstractmachines
#     21        claramartinez2
#     20            andresgoag
#     20         TantumNTatari
#     19             byingyang
#     19           mike-tatari
#     18            jasonjylin
#     17              seanchon
#     17           simranpatil
#     16         sakshi-tatari
#     15               juanfec
#     15         BrianJFeldman
#     15         jessicatatari
#     14 nathaniel-sandler-ttv
#     14              kienankb
#     14              moarwick
#     14             sabrinaan
#     14          anushamohan7
#     14           tommytatari
#     14             Jaykim148
#     13             sshirokov
#     13             tkohrumel
#     13              robkwark
#     13             mattpatch
#     12       danharristatari
#     11       mikel-at-tatari
#     11     micahelias-tatari
#     11          jianattatari
#     11        travisd-tatari
#     10       emptyset-tatari
#     10                aspall
#     10       tv-watts-tatari
#      9               dfinlay
#      9               dShah81
#      9              rfarjadi
#      8     computerGeologist
#      8             xueTatari
#      7            onmywayout
#      7       dependabot[bot]
#      7               jpotth1
#      7        bryce-manhardt
#      7           grigorovsky
#      7          nickd-tatari
#      6            leah-z-liu
#      6            JJJ-Tatari
#      6            brechichar
#      5           natanaelw67
#      5          kelly-tatari
#      5              will-vea
#      4           rudy-tatari
#      4             ajwhitley
#      4             spindle79
#      4             jkreschke
#      3               glorp47
#      3            kabirdugal
#      3                jeffcs
#      2            raychung02
#      2               nzlinus
#      2          summerrr0101
#      2        michael-tatari
#      2             jp-tatari
#      2         willis-tatari
#      1    keenanwells-tatari
#      1           tataristaku
#      1          childmike222
#      1           Mfon-tatari
#      1 congcharlieqin-tatari

# %% [markdown]
# ### Now join to 'coders' view to get employee info

# %%
with pr_counts as (
    select
      count(*) as count, user_login
    from
      github.pulls
    where
      created_at > (current_date - INTERVAL 4 month)
    group by user_login
    order by count desc
)
select 
  count, user_login, name, start, level, manager
from 
  pr_counts
inner join
  github.coders on pr_counts.user_login = github.coders.login
# Out:
# 70 rows
#  count            user_login                 name      start  level manager
#    281              dansc0de          Dan Mahoney 2021-05-24      4   Idler
#    192        stephen-tatari        Stephen Price 2021-10-04      3  ScottI
#    133               pshelby       Patrick Shelby 2020-11-09      4   Idler
#    133   patrick-strittmater  Patrick Strittmater 2021-05-24      4   Scott
#    118          calvintatari        Calvin Morrow 2021-04-26      3 Scott-I
#    114         henryzhangsta          Henry Zhang 2019-12-02      5   Scott
#    103           helloimowen        Owen Sanders  2020-08-10      3   Scott
#     96             Gerald-DT     Gerald Diep-Tran 2022-01-24      3     Jim
#     89           jeromebanks         Jerome Banks 2021-01-18      5   Scott
#     87         margot-tatari       Margot Maxwell 2022-04-25      3   Idler
#     86        rsty-instgrmpy        Russell Simco 2021-06-28      3   Scott
#     80             linda-owo           linda wang 2022-02-07      3     Jim
#     79             katiesing           Katie Sing 2021-06-07      2    Mala
#     71           brandon733t          Brandon Lee 2021-08-16      4  Jeff S
#     70                  lame            Ryan Kuhl 2018-11-26      4  Jeff S
#     64          brian-tatari         Brian Olecki 2021-05-24      4    Reno
#     63           dave-kimble          Dave Kimble 2022-04-11      4     Jim
#     60             benhorntv    Ben Horn @ Tatari 2021-05-24      2   Scott
#     59               nkbelow       Nicholas Below 2019-11-04      3     Jim
#     58         keegan-tatari      Keegan Ferrando 2021-11-01      4   Idler
#     57           turing4ever              Yi Wang 2020-10-19      4     Jim
#     54               dgaldon         David Galdon 2021-05-17      4   Peter
#     54           bobattatari         Bob Lockwood 2021-11-15      3   David
#     54             KyleZouFE             Kyle Zou 2021-09-01      2   David
#     52              itsliana        Liana Sanders 2019-10-28      3   Peter
#     45              npalombo         Nick Palombo 2021-09-01      4     Jim
#     43        lucas-baik-ttv           Lucas Baik 2021-12-01      4    Mala
#     43             sevenfour         Leo Alekseev 2022-01-03      3   David
#     42            nick-kl4us         Nick Gentile 2021-08-09      3    Mala
#     41               igandhi           Ike Gandhi 2019-11-11      4   Peter
#     41       Cody123Anderson        Cody Anderson 2021-04-26      4     Jim
#     40             alexkahan           Alex Kahan 2022-06-01      1    Reno
#     38           alexfraczak         Alex Fraczak 2021-08-30      4    Reno
#     36         JamesATrevino        James Trevino 2022-01-03      3     Jim
#     36               tlovely         Tyler Lovely 2021-12-06      4     Jim
#     35             waegerter     William Aegerter 2020-11-02      5  Jeff S
#     33              dog-face       noah nito vito 2020-03-09      3    Reno
#     32              sirtorry           Torry Yang 2022-03-28      2    Mala
#     30                  lrod           Leslie Rod 2021-08-16      4 Scott P
#     29           yumeng-liao          Yumeng Liao 2021-03-22      2   Peter
#     29             tmoney100        Taylor Allred 2021-09-27      3     Jim
#     29               jglopez   Jeremy Glenn Lopez 2021-05-24      2 Scott-I
#     26         daniel-a-leon          Daniel Leon 2021-03-01      2     Jim
#     25             janina213         Janina Mejia 2019-01-07      3     Jim
#     24          georgegaytan        George Gaytan 2019-10-29      3    Reno
#     21      abstractmachines         Amanda Falke 2021-12-07      3   Peter
#     21        claramartinez2 Clara Martinez Rubio 2022-04-18      3    Mala
#     20         TantumNTatari       Tantum Nilkaew 2022-03-15      1   David
#     19             byingyang          Brad Yinger 2020-10-06      4  Jeff S
#     19           mike-tatari         Mike Bartoli 2022-05-02      4    Jeff
#     17              seanchon            Sean Chon 2020-11-09      4   David
#     15         BrianJFeldman        Brian Feldman 2018-09-05      4    Mala
#     14 nathaniel-sandler-ttv    Nathaniel Sandler 2022-03-28      3    Mala
#     14              kienankb  kienan knight-boehm 2020-11-09      2   David
#     13             sshirokov       Slava Shirokov 2021-01-11      4     Jim
#     11       mikel-at-tatari      Michael Librodo 2016-11-15      5    Reno
#     11        travisd-tatari         Travis Doane 2021-10-18      3    Reno
#     10       emptyset-tatari             Alan Fay 2021-04-26      4   David
#      9               dfinlay          Dave Finlay 2021-05-17      4    Mala
#      9               dShah81           Dhara Shah 2022-01-10      4    Mala
#      9              rfarjadi         Ryan Farjadi 2017-07-10      5   Scott
#      7               jpotth1      Jordan Potthoff 2021-06-14      4   Bruce
#      7          nickd-tatari           Nick Davis 2022-05-02      3     Jim
#      6            leah-z-liu             Leah Liu 2021-03-22      2   Bruce
#      5              will-vea          William Vea 2022-02-14      2   Bruce
#      3               glorp47        Haris Qureshi 2021-05-10      3    Mala
#      2            raychung02            Ray Chung 2021-01-18      2  Barone
#      2             jp-tatari            JP Ciceri 2021-12-07      2   Dan S
#      2         willis-tatari      Willis Schubert 2022-04-11      1   Idler
#      1    keenanwells-tatari         Keenan Wells 2022-06-27      3    Reno

# %% [markdown]
# ### Now count JIRA tickets by person

# %%
  select 
     count(*) as count, fields_assignee_displayName
  from 
     jira.issues
  where fields_created > (current_date - interval 4 month)
  group by all
  order by count desc
# Out:
# 158 rows
#  count fields_assignee_displayName
#    907                         NaN
#    182             Bruce Rechichar
#    117                    Will Vea
#    102                   Ray Chung
#     94                  Rifat Khan
#     89                 Jervin Cruz
#     87                    Leah Liu
#     80             Majken Longlade
#     79                Victor Ortiz
#     78             Jordan Potthoff
#     73               Manisha Patel
#     72               Michael Smith
#     69                Anusha Mohan
#     62                  Ellen Xiao
#     59                 Kabir Dugal
#     58                  Josh Demeo
#     54               Solomon Klein
#     54              Abdullah Spall
#     53              Bryce Manhardt
#     49                  Sabrina An
#     47                 Jessica Cai
#     46                   Rob Kwark
#     45               Calvin Morrow
#     43                 Dan Mahoney
#     42                Leo Alekseev
#     40                 Tommy Hogan
#     39                  Ike Gandhi
#     38          Vasily Grigorovsky
#     38                  Matt Patch
#     38                David Galdon
#     38                  Tim Morton
#     36                   Matt Agin
#     33               Stephen Price
#     33          Jeremy Glenn Lopez
#     32                  Mike Child
#     32           Alessandro Gracia
#     32                Bob Lockwood
#     31                      Ada Li
#     30              Patrick Shelby
#     30               Taylor Allred
#     28         Alexandre Dieudonne
#     27               Brian Feldman
#     26                    Kyle Zou
#     26                Nick Gentile
#     26                Nick Palombo
#     25             Keegan Ferrando
#     25                Mike Swinson
#     23              Thuy-Van Watts
#     22            William Aegerter
#     22               Cody Anderson
#     22                   Ryan Kuhl
#     22                Tyler Lovely
#     21               Liana Sanders
#     21               Farbod Safaei
#     21                  Alex Kahan
#     21                Kyle Kosnoff
#     21     Leslie Rodriguez Garcia
#     21                  Lucas Baik
#     20                Jaeyeong Kim
#     20               Russell Simco
#     20                    Wei Chen
#     20                   Noah Vito
#     19                  Katie Sing
#     19                     Xue Gao
#     19                     Yi Wang
#     19               George Gaytan
#     18             Kaitlin Rasborn
#     18               Mala Munisamy
#     18                Travis Doane
#     18              Margot Maxwell
#     18               James Trevino
#     18                 Yumeng Liao
#     17                Rudy Gilmore
#     17                   Summer Ye
#     17                    Toni Poe
#     16                   Brian Sam
#     16                   Kyle Dinh
#     16                 Brent White
#     16                  Owen Karpf
#     16                Owen Sanders
#     15                Brian Olecki
#     14               Dan Stynchula
#     13                  Zishu Wang
#     13                David Kimble
#     13            Gerald Diep-Tran
#     13                   JP Ciceri
#     13                Mike Librodo
#     12                Janina Mejia
#     12                    Ben Horn
#     12                Tim Kohrumel
#     11                 Daniel Leon
#     11                  Nick Below
#     11                Jake Reschke
#     11              Tantum Nilkaew
#     10                 Henry Zhang
#     10        Andres Gomez Agudelo
#     10                   Jason Lin
#     10                 Brad Yinger
#     10           Nathaniel Sandler
#     10                 Brandon Lee
#      9               Daniel Harris
#      9                  Jim Lyndon
#      9                  Linda Wang
#      9                Rahul Sharma
#      9                 Maxwell Guo
#      9              Peter Morawiec
#      9         Kienan Knight-Boehm
#      9                     Jian Lu
#      9                Amanda Falke
#      8                    Annie Xu
#      8                 Sakshi Garg
#      8                Jerome Banks
#      8                    Ty McRae
#      8                Ryan Farjadi
#      8                 Luan Truong
#      7                 Dave Finlay
#      7              Tyrone Chouhan
#      7                 Kelly Chung
#      7         Patrick Strittmater
#      7                   Sean Chon
#      6              Lin O'Driscoll
#      6                  Juan Rueda
#      6                  Dhara Shah
#      6             Elizabeth Spear
#      6              Slava Shirokov
#      6                Alex Fraczak
#      6                     Gary Ye
#      6               Haris Qureshi
#      5                Simran Patil
#      5                 Scott Idler
#      5                  Jimmy Shao
#      5                    Alan Fay
#      5                  Nick Davis
#      5                  Torry Yang
#      5                  Reno Brown
#      4             Natanael Wijaya
#      4             Willis Schubert
#      4        Clara Martinez Rubio
#      4               Russ O'Reagan
#      4              Alex Markaryan
#      3              Nicolas Zapata
#      3                 Tim Gumbley
#      2                Keenan Wells
#      2                Truxten Cook
#      2               Harshal Dalvi
#      2                Mike Bartoli
#      2                   David Hwu
#      1              Polina Frolova
#      1          Tatari Help Center
#      1               Celine Nguyen
#      1             Scott Persinger
#      1                 Yarik Vyrva
#      1             Theresa Amrhein
#      1                    Julia Wu
#      1                Jinjin Jiang
#      1              Kevin Thompson
#      1           Mitchell Panajian
#      1              Chad Catherine

# %% [markdown]
# ### Now query both JIRA issues and PR counts together into a view

# %%
create or replace view github.prs_and_tickets as (
    with jira_issues as (
      select 
         count(*) as count, fields_assignee_displayName as name
      from 
         jira.issues
      where fields_created > (current_date - interval 4 month)
      group by all
      order by count desc
    ),
    pr_counts as (
        select
          count(*) as count, user_login
        from
          github.pulls
        where
          created_at > (current_date - INTERVAL 4 month)
        group by user_login
        order by count desc
    )
    select 
      user_login, coders.name, start, level, manager, pr_counts.count as prs, jira_issues.count as tickets
    from 
      pr_counts
    inner join
      github.coders on pr_counts.user_login = github.coders.login
    join
      jira_issues on ltrim(rtrim(lower(github.coders.name))) = ltrim(rtrim(lower(jira_issues.name)))
    order by (pr_counts.count + jira_issues.count) desc
)
# Out:
# 0 rows
# Empty DataFrame
# Columns: [Count]
# Index: []

# %%
select * from github.prs_and_tickets
# Out:
# 63 rows
#            user_login                 name      start  level manager  prs  tickets
#              dansc0de          Dan Mahoney 2021-05-24      4   Idler  281       43
#        stephen-tatari        Stephen Price 2021-10-04      3  ScottI  192       33
#          calvintatari        Calvin Morrow 2021-04-26      3 Scott-I  118       45
#               pshelby       Patrick Shelby 2020-11-09      4   Idler  133       30
#   patrick-strittmater  Patrick Strittmater 2021-05-24      4   Scott  133        7
#         henryzhangsta          Henry Zhang 2019-12-02      5   Scott  114       10
#           helloimowen        Owen Sanders  2020-08-10      3   Scott  103       16
#             Gerald-DT     Gerald Diep-Tran 2022-01-24      3     Jim   96       13
#        rsty-instgrmpy        Russell Simco 2021-06-28      3   Scott   86       20
#         margot-tatari       Margot Maxwell 2022-04-25      3   Idler   87       18
#            raychung02            Ray Chung 2021-01-18      2  Barone    2      102
#             katiesing           Katie Sing 2021-06-07      2    Mala   79       19
#           jeromebanks         Jerome Banks 2021-01-18      5   Scott   89        8
#            leah-z-liu             Leah Liu 2021-03-22      2   Bruce    6       87
#               dgaldon         David Galdon 2021-05-17      4   Peter   54       38
#                  lame            Ryan Kuhl 2018-11-26      4  Jeff S   70       22
#             linda-owo           linda wang 2022-02-07      3     Jim   80        9
#           bobattatari         Bob Lockwood 2021-11-15      3   David   54       32
#               jpotth1      Jordan Potthoff 2021-06-14      4   Bruce    7       78
#             sevenfour         Leo Alekseev 2022-01-03      3   David   43       42
#         keegan-tatari      Keegan Ferrando 2021-11-01      4   Idler   58       25
#           brandon733t          Brandon Lee 2021-08-16      4  Jeff S   71       10
#               igandhi           Ike Gandhi 2019-11-11      4   Peter   41       39
#             KyleZouFE             Kyle Zou 2021-09-01      2   David   54       26
#          brian-tatari         Brian Olecki 2021-05-24      4    Reno   64       15
#           turing4ever              Yi Wang 2020-10-19      4     Jim   57       19
#              itsliana        Liana Sanders 2019-10-28      3   Peter   52       21
#              npalombo         Nick Palombo 2021-09-01      4     Jim   45       26
#            nick-kl4us         Nick Gentile 2021-08-09      3    Mala   42       26
#        lucas-baik-ttv           Lucas Baik 2021-12-01      4    Mala   43       21
#       Cody123Anderson        Cody Anderson 2021-04-26      4     Jim   41       22
#               jglopez   Jeremy Glenn Lopez 2021-05-24      2 Scott-I   29       33
#             alexkahan           Alex Kahan 2022-06-01      1    Reno   40       21
#             tmoney100        Taylor Allred 2021-09-27      3     Jim   29       30
#               tlovely         Tyler Lovely 2021-12-06      4     Jim   36       22
#             waegerter     William Aegerter 2020-11-02      5  Jeff S   35       22
#         JamesATrevino        James Trevino 2022-01-03      3     Jim   36       18
#           yumeng-liao          Yumeng Liao 2021-03-22      2   Peter   29       18
#           alexfraczak         Alex Fraczak 2021-08-30      4    Reno   38        6
#          georgegaytan        George Gaytan 2019-10-29      3    Reno   24       19
#         BrianJFeldman        Brian Feldman 2018-09-05      4    Mala   15       27
#             janina213         Janina Mejia 2019-01-07      3     Jim   25       12
#         daniel-a-leon          Daniel Leon 2021-03-01      2     Jim   26       11
#              sirtorry           Torry Yang 2022-03-28      2    Mala   32        5
#         TantumNTatari       Tantum Nilkaew 2022-03-15      1   David   20       11
#      abstractmachines         Amanda Falke 2021-12-07      3   Peter   21        9
#        travisd-tatari         Travis Doane 2021-10-18      3    Reno   11       18
#             byingyang          Brad Yinger 2020-10-06      4  Jeff S   19       10
#        claramartinez2 Clara Martinez Rubio 2022-04-18      3    Mala   21        4
# nathaniel-sandler-ttv    Nathaniel Sandler 2022-03-28      3    Mala   14       10
#              seanchon            Sean Chon 2020-11-09      4   David   17        7
#              kienankb  kienan knight-boehm 2020-11-09      2   David   14        9
#           mike-tatari         Mike Bartoli 2022-05-02      4    Jeff   19        2
#             sshirokov       Slava Shirokov 2021-01-11      4     Jim   13        6
#              rfarjadi         Ryan Farjadi 2017-07-10      5   Scott    9        8
#               dfinlay          Dave Finlay 2021-05-17      4    Mala    9        7
#             jp-tatari            JP Ciceri 2021-12-07      2   Dan S    2       13
#               dShah81           Dhara Shah 2022-01-10      4    Mala    9        6
#       emptyset-tatari             Alan Fay 2021-04-26      4   David   10        5
#          nickd-tatari           Nick Davis 2022-05-02      3     Jim    7        5
#               glorp47        Haris Qureshi 2021-05-10      3    Mala    3        6
#         willis-tatari      Willis Schubert 2022-04-11      1   Idler    2        4
#    keenanwells-tatari         Keenan Wells 2022-06-27      3    Reno    1        2

# %% [markdown]
# ### And now export the view to Google Sheets

# %%
export github.prs_and_tickets to gsheets ('PRs and Ticket stats - ' || current_date) overwrite
# Out:
# Wrote 64 rows to sheet
# Exported query result to 'PRs and Ticket stats - 2022-08-03'

# %%
email notebook to 'scottp@berkeleyzone.net'
# Out:
# Notebook path is: /Users/scottp/src/unify/notebooks/Coder Stats.ipynb
