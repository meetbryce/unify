# %% [markdown]
# ## Count PRs created and JIRA tickets assigned per IC over last 4 months

# %% [markdown]
# **Make sure to run the 'Build Employees' notebook first to create the 'coders' view**

# %%
count github.coders
# Out:
# 1 row
#  count__
#       74

# %% [markdown]
# ### Count PRs by user over last 4 months

# %%
select
  count(*) as count, user_login
from
  github.pulls
where
  created_at > (now() - INTERVAL 4 month)
group by user_login
order by count desc
# Out:
# 128 rows
#  count            user_login
#    279              dansc0de
#    170        stephen-tatari
#    153         henryzhangsta
#    150               pshelby
#    118         margot-tatari
#    118   patrick-strittmater
#    117          calvintatari
#    111         willis-tatari
#     96                  lrod
#     77           helloimowen
#     76              npalombo
#     74           dave-kimble
#     71               nkbelow
#     69             katiesing
#     66        rsty-instgrmpy
#     63         keegan-tatari
#     58          brian-tatari
#     57           bobattatari
#     56               dgaldon
#     55             waegerter
#     54             benhorntv
#     54             alexkahan
#     53               ellen-x
#     52           brandon733t
#     52        lucas-baik-ttv
#     51             byingyang
#     51              itsliana
#     51             linda-owo
#     50           alexfraczak
#     48               igandhi
#     45          georgegaytan
#     45               tlovely
#     43              tatar-ye
#     41    truxtencook-tatari
#     39             Gerald-DT
#     39             KyleZouFE
#     39             sevenfour
#     38           turing4ever
#     38              kyle-ttv
#     37              dog-face
#     37             janina213
#     37             tmoney100
#     36       Cody123Anderson
#     35            nick-kl4us
#     34           mike-tatari
#     33          kelly-tatari
#     32              moarwick
#     32              sirtorry
#     29    rahulsharma-tatari
#     29           simranpatil
#     29       mikel-at-tatari
#     28         JamesATrevino
#     28              seanchon
#     27               jglopez
#     27            vicortiz94
#     27           yumeng-liao
#     25      abstractmachines
#     25             Kyle-Dinh
#     24         truongluan303
#     24         TantumNTatari
#     24        claramartinez2
#     24         daniel-a-leon
#     24          joshua-demeo
#     23            andresgoag
#     22           jeromebanks
#     22         BrianJFeldman
#     19           natanaelw67
#     19           tataristaku
#     19              kienankb
#     19                  lame
#     19 nathaniel-sandler-ttv
#     19         sakshi-tatari
#     18        timothydmorton
#     18             weitatari
#     17         escote-tatari
#     15             Jaykim148
#     15           tommytatari
#     15             xueTatari
#     15               juanfec
#     15              robkwark
#     15       danharristatari
#     14         jessicatatari
#     14        travisd-tatari
#     14               dShah81
#     14       dependabot[bot]
#     14             sabrinaan
#     13     micahelias-tatari
#     13            jasonjylin
#     12              rfarjadi
#     12             mattpatch
#     12          jianattatari
#     11             sshirokov
#     11            leah-z-liu
#     10           grigorovsky
#      9     computerGeologist
#      9                aspall
#      9            onmywayout
#      9          nickd-tatari
#      8       tv-watts-tatari
#      8               glorp47
#      7          anushamohan7
#      7            kabirdugal
#      7             jp-tatari
#      7               dfinlay
#      6            raychung02
#      6           Jeff-tatari
#      6          summerrr0101
#      6          tonyo-tatari
#      6           Mfon-tatari
#      6        bryce-manhardt
#      6       emptyset-tatari
#      6              will-vea
#      5               jpotth1
#      4             tkohrumel
#      4             ajwhitley
#      4           Anna-Tatari
#      4           rudy-tatari
#      3                jeffcs
#      3             jkreschke
#      3             spindle79
#      3      JimmyShao-tatari
#      2           manisha-pat
#      2        patrick-tatari
#      2    keenanwells-tatari
#      1        scottpersinger
#      1     Owen-Karpf-Tatari
#      1 congcharlieqin-tatari
#      1               nzlinus

# %% [markdown]
# ### Now join to 'coders' view to get employee info

# %%
with pr_counts as (
    select
      count(*) as count, user_login
    from
      github.pulls
    where
      created_at > (now() - INTERVAL 4 month)
    group by user_login
    order by count desc
)
select 
  count, user_login, name, start, lvl, manager
from 
  pr_counts
inner join
  github.coders on pr_counts.user_login = github.coders.login
# Out:
# 71 rows
#  count            user_login                 name      start lvl manager
#    279              dansc0de          Dan Mahoney 2021-05-23   4   Idler
#    170        stephen-tatari        Stephen Price 2021-10-03   3  ScottI
#    153         henryzhangsta          Henry Zhang 2019-12-01   5   Scott
#    150               pshelby       Patrick Shelby 2020-11-08   4   Idler
#    118         margot-tatari       Margot Maxwell 2022-04-24   3   Idler
#    118   patrick-strittmater  Patrick Strittmater 2021-05-23   4   Scott
#    117          calvintatari        Calvin Morrow 2021-04-25   3 Scott-I
#    111         willis-tatari      Willis Schubert 2022-04-10   1   Idler
#     96                  lrod           Leslie Rod 2021-08-15   4 Scott P
#     77           helloimowen        Owen Sanders  2020-08-09   3   Scott
#     76              npalombo         Nick Palombo 2021-08-31   4     Jim
#     74           dave-kimble          Dave Kimble 2022-04-10   4     Jim
#     71               nkbelow           Nick Below 2019-11-03   3     Jim
#     69             katiesing           Katie Sing 2021-06-06   2    Mala
#     66        rsty-instgrmpy        Russell Simco 2021-06-27   3   Scott
#     63         keegan-tatari      Keegan Ferrando 2021-10-31   4   Idler
#     58          brian-tatari         Brian Olecki 2021-05-23   4    Reno
#     57           bobattatari         Bob Lockwood 2021-11-14   3   David
#     56               dgaldon         David Galdon 2021-05-16   4   Peter
#     55             waegerter     William Aegerter 2020-11-01   5  Jeff S
#     54             benhorntv    Ben Horn @ Tatari 2021-05-23   2   Scott
#     54             alexkahan           alex kahan 2022-05-31   1    Reno
#     52           brandon733t          Brandon Lee 2021-08-15   4  Jeff S
#     52        lucas-baik-ttv           Lucas Baik 2021-11-30   4    Mala
#     51             byingyang          Brad Yinger 2020-10-05   4  Jeff S
#     51              itsliana        Liana Sanders 2019-10-27   3   Peter
#     51             linda-owo           linda wang 2022-02-06   3     Jim
#     50           alexfraczak         Alex Fraczak 2021-08-29   4    Reno
#     48               igandhi           Ike Gandhi 2019-11-10   4   Peter
#     45          georgegaytan        George Gaytan 2019-10-28   3    Reno
#     45               tlovely         Tyler Lovely 2021-12-05   4     Jim
#     39             Gerald-DT     Gerald Diep-Tran 2022-01-23   3     Jim
#     39             KyleZouFE             Kyle Zou 2021-08-31   2   David
#     39             sevenfour         Leo Alekseev 2022-01-02   3   David
#     38           turing4ever              Yi Wang 2020-10-18   4     Jim
#     37              dog-face       noah nito vito 2020-03-08   3    Reno
#     37             janina213         Janina Mejia 2019-01-06   3     Jim
#     37             tmoney100        Taylor Allred 2021-09-26   3     Jim
#     36       Cody123Anderson        Cody Anderson 2021-04-25   4     Jim
#     35            nick-kl4us         Nick Gentile 2021-08-08   3    Mala
#     34           mike-tatari         Mike Bartoli 2022-05-01   4    Jeff
#     32              sirtorry           Torry Yang 2022-03-27   2    Mala
#     29       mikel-at-tatari      Michael Librodo 2016-11-14   5    Reno
#     28         JamesATrevino        James Trevino 2022-01-02   3     Jim
#     28              seanchon            Sean Chon 2020-11-08   4   David
#     27               jglopez   Jeremy Glenn Lopez 2021-05-23   3 Scott-I
#     27           yumeng-liao          Yumeng Liao 2021-03-21   2   Peter
#     25      abstractmachines         Amanda Falke 2021-12-06   3   Peter
#     24         TantumNTatari       Tantum Nilkaew 2022-03-14   1   David
#     24        claramartinez2 Clara Martinez Rubio 2022-04-17   3    Mala
#     24         daniel-a-leon          Daniel Leon 2021-02-28   2     Jim
#     22         BrianJFeldman        Brian Feldman 2018-09-04   4    Mala
#     19           tataristaku          Stan Kudrow 2022-06-26   4 Harshal
#     19              kienankb  kienan knight-boehm 2020-11-08   2   David
#     19                  lame            Ryan Kuhl 2018-11-25   4  Jeff S
#     19 nathaniel-sandler-ttv    Nathaniel Sandler 2022-03-27   3    Mala
#     14        travisd-tatari         Travis Doane 2021-10-17   3    Reno
#     14               dShah81           Dhara Shah 2022-01-09   4    Mala
#     12              rfarjadi         Ryan Farjadi 2017-07-09   5   Scott
#     11             sshirokov       Slava Shirokov 2021-01-10   4     Jim
#     11            leah-z-liu             Leah Liu 2021-03-21   2   Bruce
#      9          nickd-tatari           Nick Davis 2022-05-01   3     Jim
#      8               glorp47        Haris Qureshi 2021-05-09   3    Mala
#      7             jp-tatari            JP Ciceri 2021-12-06   2   Dan S
#      7               dfinlay          Dave Finlay 2021-05-16   4    Mala
#      6            raychung02            Ray Chung 2021-01-17   2  Barone
#      6          tonyo-tatari          Tony O'Dell 2022-07-31   4    Reno
#      6       emptyset-tatari             Alan Fay 2021-04-25   4   David
#      6              will-vea          William Vea 2022-02-13   2   Bruce
#      5               jpotth1      Jordan Potthoff 2021-06-13   4   Bruce
#      2    keenanwells-tatari         Keenan Wells 2022-06-26   3    Reno

# %% [markdown]
# ### Now count JIRA tickets by person

# %%
  select 
     count(*) as count, fields_assignee_displayName
  from 
     jira.issues
  where fields_created > (now() - interval 4 month)
  group by fields_assignee_displayName
  order by count desc
# Out:
# 182 rows
#  count fields_assignee_displayName
#   1423
#    324               Manisha Patel
#    283                  Rifat Khan
#    109           Vitalii Litkevich
#     89                Victor Ortiz
#     81          Vasily Grigorovsky
#     80                Anusha Mohan
#     78                 Jessica Cai
#     77               Michael Smith
#     76                 Kabir Dugal
#     75               Solomon Klein
#     74                   Rob Kwark
#     71          Viacheslav Shostak
#     70                  Josh Demeo
#     69              Abdullah Spall
#     68                 Jervin Cruz
#     67                  Ellen Xiao
#     64                 Tommy Hogan
#     61                    Will Vea
#     61                    Leah Liu
#     58             Bruce Rechichar
#     57              Bryce Manhardt
#     56                  Sabrina An
#     55           Alessandro Gracia
#     55                  Matt Patch
#     54                   Ray Chung
#     53                   Matt Agin
#     53                David Galdon
#     51              Yevhen Shakhov
#     50     Nataliia Myroshnychenko
#     49                     Xue Gao
#     47             Majken Longlade
#     46                Oleg Gubanov
#     46                Leo Alekseev
#     46                Yana Belokoz
#     44                Bob Lockwood
#     44               Dmitriy Butko
#     44         Alexandre Dieudonne
#     43                  Ike Gandhi
#     43              Thuy-Van Watts
#     43               Calvin Morrow
#     43                      Ada Li
#     43                Kyle Kosnoff
#     41             Willis Schubert
#     40                Tyler Lovely
#     40                  Owen Karpf
#     40             Jordan Potthoff
#     39                  Alex Kahan
#     39               Stephen Price
#     39                 Dan Mahoney
#     38                Rudy Gilmore
#     35                Mike Swinson
#     35            William Aegerter
#     35               Taylor Allred
#     34               Liana Sanders
#     33              Patrick Shelby
#     33                Amanda Falke
#     31            Roman Pavlushkov
#     31                Nick Palombo
#     31                Owen Sanders
#     30          Jeremy Glenn Lopez
#     29     Leslie Rodriguez Garcia
#     29                   Noah Vito
#     29               George Gaytan
#     28              Polina Frolova
#     27               Brian Feldman
#     27                   Summer Ye
#     27                   Brian Sam
#     27                Jaeyeong Kim
#     27               Dan Stynchula
#     26                Travis Doane
#     26                   JP Ciceri
#     25             Keegan Ferrando
#     25                    Jeff Cai
#     24                    Ben Horn
#     24                Brian Olecki
#     24                    Kyle Zou
#     24                  Anna Young
#     24                  Zishu Wang
#     24                Janina Mejia
#     23             Kaitlin Rasborn
#     23                    Wei Chen
#     23                     Yi Wang
#     23                  Katie Sing
#     22               Russell Simco
#     22                Jake Reschke
#     22              Peter Morawiec
#     22                Nick Gentile
#     21                   Sean Chon
#     21         Kienan Knight-Boehm
#     21               Cody Anderson
#     20                  Mike Child
#     20              Tantum Nilkaew
#     20                David Kimble
#     20                  Lucas Baik
#     19               Haris Qureshi
#     18                  Tim Morton
#     18              Margot Maxwell
#     17                Alex Fraczak
#     17                    Toni Poe
#     16               Mala Munisamy
#     16           Nathaniel Sandler
#     16                 Stan Kudrow
#     15                Lucas Miller
#     15        Andres Gomez Agudelo
#     15                 Yumeng Liao
#     15                  Nick Below
#     14                Rahul Sharma
#     14                   Kyle Dinh
#     14                Simran Patil
#     14                  Linda Wang
#     13                  Nick Davis
#     13             Natanael Wijaya
#     13                 Brandon Lee
#     13               Farbod Safaei
#     13            Anton Slobodskyi
#     13                   Ryan Kuhl
#     13                 Daniel Leon
#     12                 Sakshi Garg
#     12               Daniel Harris
#     12                     Jian Lu
#     12               James Trevino
#     12                   Jason Lin
#     11                 Henry Zhang
#     11                  Dhara Shah
#     11                Mike Librodo
#     11                 Brent White
#     11                 Maxwell Guo
#     11                  Juan Rueda
#     11                  Jim Lyndon
#     10            Gerald Diep-Tran
#     10         Patrick Strittmater
#     10                 Brad Yinger
#     10                    Annie Xu
#     10        Clara Martinez Rubio
#      8              Slava Shirokov
#      8                 Dave Finlay
#      8         Gennadii Kravchenko
#      8                 Kelly Chung
#      7              Mfon Afangideh
#      7                     Gary Ye
#      7                  Jimmy Shao
#      7                  Torry Yang
#      7                    Ty McRae
#      7             Elizabeth Spear
#      6              Tyrone Chouhan
#      6          Michael Collington
#      6                 Micah Elias
#      6                  Andrew Kim
#      6                 Tim Gumbley
#      6              Nicolas Zapata
#      4                   David Hwu
#      4                  Vlad Belik
#      4                Ryan Farjadi
#      4                 Tony O'Dell
#      4                Truxten Cook
#      3                Mike Bartoli
#      3                Jerome Banks
#      2                  Patrick He
#      2                Keenan Wells
#      2                 Scott Idler
#      2                Michelle Lei
#      2              Lin O'Driscoll
#      2                  Jeff Stamm
#      1            Erika Clingerman
#      1                   Jena Vint
#      1              Leo Perenzuela
#      1               Russ O'Reagan
#      1               Harshal Dalvi
#      1                  Caleb Rouw
#      1                 Charlie Qin
#      1             Scott Persinger
#      1                Ani Govindan
#      1              Alex Markaryan
#      1                  Max Zaydes
#      1             Aaron Perlstein
#      1              Matt Giannetti
#      1                    Alan Fay
#      1                 Yarik Vyrva
#      1                Yulia Koshel
#      1             Theresa Amrhein
#      1               Lizzie Sandie

# %% [markdown]
# ### Now query both JIRA issues and PR counts together into a view

# %%
create or replace view github.prs_and_tickets as (
    with jira_issues as (
      select 
         count(*) as count, fields_assignee_displayName as name
      from 
         jira.issues
      where fields_created > (now() - interval 4 month)
      group by fields_assignee_displayName
      order by count desc
    ),
    pr_counts as (
        select
          count(*) as count, user_login
        from
          github.pulls
        where
          created_at > (now() - INTERVAL 4 month)
        group by user_login
        order by count desc
    )
    select 
      user_login, coders.name, start, lvl, manager, pr_counts.count as prs, jira_issues.count as tickets
    from 
      pr_counts
    inner join
      github.coders on pr_counts.user_login = github.coders.login
    join
      jira_issues on ltrim(rtrim(lower(github.coders.name))) = ltrim(rtrim(lower(jira_issues.name)))
    order by (pr_counts.count + jira_issues.count) desc
)
# Out:
# 0 rows
# Empty DataFrame
# Columns: []
# Index: []

# %%
select * from github.prs_and_tickets
# Out:
# 64 rows
#            user_login                 name      start  level manager  prs  tickets
#              dansc0de          Dan Mahoney 2021-05-24      4   Idler  265       42
#        stephen-tatari        Stephen Price 2021-10-04      3  ScottI  183       41
#          calvintatari        Calvin Morrow 2021-04-26      3 Scott-I  119       52
#   patrick-strittmater  Patrick Strittmater 2021-05-24      4   Scott  156        9
#               pshelby       Patrick Shelby 2020-11-09      4   Idler  125       31
#         margot-tatari       Margot Maxwell 2022-04-25      3   Idler   90       24
#               dgaldon         David Galdon 2021-05-17      4   Peter   58       48
#           bobattatari         Bob Lockwood 2021-11-15      3   David   63       42
#           helloimowen        Owen Sanders  2020-08-10      3   Scott   75       23
#             katiesing           Katie Sing 2021-06-07      2    Mala   78       15
#               igandhi           Ike Gandhi 2019-11-11      4   Peter   46       47
#         keegan-tatari      Keegan Ferrando 2021-11-01      4   Idler   60       30
#         henryzhangsta          Henry Zhang 2019-12-02      5   Scott   75       14
#          brian-tatari         Brian Olecki 2021-05-24      4    Reno   63       24
#              itsliana        Liana Sanders 2019-10-28      3   Peter   52       35
#        rsty-instgrmpy        Russell Simco 2021-06-28      3   Scott   69       17
#             sevenfour         Leo Alekseev 2022-01-03      3   David   42       44
#            raychung02            Ray Chung 2021-01-18      2  Barone    5       79
#              npalombo         Nick Palombo 2021-09-01      4     Jim   59       24
#             alexkahan           alex kahan 2022-06-01      1    Reno   51       32
#           jeromebanks         Jerome Banks 2021-01-18      5   Scott   74        8
#             Gerald-DT     Gerald Diep-Tran 2022-01-24      3     Jim   61       20
#               tlovely         Tyler Lovely 2021-12-06      4     Jim   43       35
#            leah-z-liu             Leah Liu 2021-03-22      2   Bruce    7       71
#             waegerter     William Aegerter 2020-11-02      5  Jeff S   46       31
#             KyleZouFE             Kyle Zou 2021-09-01      2   David   48       26
#           turing4ever              Yi Wang 2020-10-19      4     Jim   50       22
#        lucas-baik-ttv           Lucas Baik 2021-12-01      4    Mala   45       27
#             linda-owo           linda wang 2022-02-07      3     Jim   56       14
#               jglopez   Jeremy Glenn Lopez 2021-05-24      2 Scott-I   32       37
#             tmoney100        Taylor Allred 2021-09-27      3     Jim   32       35
#           brandon733t          Brandon Lee 2021-08-16      4  Jeff S   56       10
#               jpotth1      Jordan Potthoff 2021-06-14      4   Bruce    6       59
#          georgegaytan        George Gaytan 2019-10-29      3    Reno   35       28
#       Cody123Anderson        Cody Anderson 2021-04-26      4     Jim   40       22
#            nick-kl4us         Nick Gentile 2021-08-09      3    Mala   35       25
#         JamesATrevino        James Trevino 2022-01-03      3     Jim   35       19
#                  lame            Ryan Kuhl 2018-11-26      4  Jeff S   34       18
#         BrianJFeldman        Brian Feldman 2018-09-05      4    Mala   17       35
#           yumeng-liao          Yumeng Liao 2021-03-22      2   Peter   27       22
#      abstractmachines         Amanda Falke 2021-12-07      3   Peter   21       26
#           alexfraczak         Alex Fraczak 2021-08-30      4    Reno   37        8
#         TantumNTatari       Tantum Nilkaew 2022-03-15      1   David   23       20
#         willis-tatari      Willis Schubert 2022-04-11      1   Idler   14       28
#              sirtorry           Torry Yang 2022-03-28      2    Mala   35        6
#             janina213         Janina Mejia 2019-01-07      3     Jim   29       11
#         daniel-a-leon          Daniel Leon 2021-03-01      2     Jim   27       12
#           mike-tatari         Mike Bartoli 2022-05-02      4    Jeff   28        4
#              seanchon            Sean Chon 2020-11-09      4   David   18       14
#        travisd-tatari         Travis Doane 2021-10-18      3    Reno    9       22
#              kienankb  kienan knight-boehm 2020-11-09      2   David   16       14
#        claramartinez2 Clara Martinez Rubio 2022-04-18      3    Mala   22        6
#             byingyang          Brad Yinger 2020-10-06      4  Jeff S   18        9
# nathaniel-sandler-ttv    Nathaniel Sandler 2022-03-28      3    Mala   17        9
#             sshirokov       Slava Shirokov 2021-01-11      4     Jim   12       11
#             jp-tatari            JP Ciceri 2021-12-07      2   Dan S    2       19
#          nickd-tatari           Nick Davis 2022-05-02      3     Jim    7       12
#               glorp47        Haris Qureshi 2021-05-10      3    Mala    5       13
#              rfarjadi         Ryan Farjadi 2017-07-10      5   Scott    9        7
#               dShah81           Dhara Shah 2022-01-10      4    Mala    4        7
#           tataristaku          Stan Kudrow 2022-06-27      4 Harshal    7        3
#       emptyset-tatari             Alan Fay 2021-04-26      4   David    6        4
#               dfinlay          Dave Finlay 2021-05-17      4    Mala    3        5
#    keenanwells-tatari         Keenan Wells 2022-06-27      3    Reno    1        2

# %% [markdown]
# ### And now export the view to Google Sheets

# %%
$name=select 'PRs and Ticket stats - ' || cast(date_trunc('day',now()) as varchar)
# Out:
# 1 row
# concat__PRs_and_Ticket_stats______CAST_date_trunc__day___now______varchar___
#                                   PRs and Ticket stats - 2022-09-15 00:00:00

# %%
export github.prs_and_tickets to gsheets $name overwrite
# Out:
# Syntax error: failed at position 1 ('export'): export github.

# %%
email github.prs_and_tickets to 'scottp@berkeleyzone.net'
# Out:
# Emailing github.prs_and_tickets to ['scottp@berkeleyzone.net']
